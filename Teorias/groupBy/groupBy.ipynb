# %% [markdown]
# ---
# layout: page
# title: GroupBy
# nav_order: 6
# ---
# [<img src="https://raw.githubusercontent.com/flaviovdf/fcd/master/assets/colab_favicon_small.png" style="float: right;">](https://colab.research.google.com/github/flaviovdf/fcd/blob/master/_lessons/06-GroupBy.ipynb)
#
# # Tópico 6 – Mais consultas e GroupBy
# {: .no_toc .mb-2 }
#
# Vamos aprender como agrupar a sumarizar dados!
# {: .fs-6 .fw-300 }
#
# {: .no_toc .text-delta }
# Resultados Esperados
#
# 1. Entender a função `groupby`
# 1. Ter um pouco de noção do potêncial de pandas
#
# {: .no_toc .text-delta }
# Material Adaptado do [DSC10 (UCSD)](https://dsc10.com/)
#
# Os dados de hoje estão [aqui (Afonso Pena)](https://raw.githubusercontent.com/flaviovdf/fcd/main/assets/06-GroupBy/data/afonso_pena.csv) e [aqui (IMDB)](https://raw.githubusercontent.com/flaviovdf/fcd/main/assets/06-GroupBy/data/imdb.csv)

# %%
# Descomente e execute as linhas a seguir para usar o BabyPandas e o PandasTutor
# (faça isso apenas se não tiver instalado ainda)
# ! pip install babypandas
# ! pip install pandas_tutor

# %%
import pandas as pd
import numpy as np


# Estamos importando o matplotlib pela primeira vez.
# Serve para fazer gráficos
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
# Esssas linhas servem para que o Pandas Tutor execute
# %reload_ext pandas_tutor
# %set_pandas_tutor_options {'projectorMode': True}

# %% [markdown]
# ### Hoje
#
# - Recapitulação: consultas.
# - Consultas com múltiplas condições.
# - Grupo por.
# - Prática extra, incluindo problemas de desafio.

# %% [markdown]
# ### Sobre os dados: Ainda estamos na feira da Afonso Pena
#
# O DataFrame `df` contém dados dos feirantes da Afonso Pena

# %%
# para rodar no colab use 'https://raw.githubusercontent.com/flaviovdf/fcd/main/assets/06-GroupBy/data/afonso_pena.csv'
# df = pd.read_csv('afonso_pena.csv')

df = pd.read_csv('https://raw.githubusercontent.com/flaviovdf/fcd/main/assets/06-GroupBy/data/afonso_pena.csv')

produtos = df.get('NUMERO_PRODUTOS_CADASTRADOS')
area = df.get('AREA')

df = df.assign(
    DENSIDADE= produtos / area
)

df = df.set_index('ID_FEIRA_AFONSO_PENA_BARRACA')
df.head()
# Out:
#                              CODIGO_VAGA  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                             F.F2.V016
# 84                             G.F3.V052
# 85                             E.F4.V003
# 86                             E.F2.V004
# 87                             D.F2.V016
#
#                                                            NOME_FANTASIA  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                              BARRACA CARMEN EMMANUEL DOS SANTOS SILVA
# 84                            BARRACA CARMEN FERNANDA ROCHA DE ALCANTARA
# 85                              BARRACA CARMEN LÚCIA CARVALHO DE ALMEIDA
# 86                                  BARRACA CECÍLIA PAGANO NEVES SALAZAR
# 87                                      BARRACA CÉLIA APARECIDA DE SOUZA
#
#                                                    NOME_FEIRANTE  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                              CARMEN EMMANUEL DOS SANTOS SILVA
# 84                            CARMEN FERNANDA ROCHA DE ALCANTARA
# 85                              CARMEN LÚCIA CARVALHO DE ALMEIDA
# 86                                  CECÍLIA PAGANO NEVES SALAZAR
# 87                                      CÉLIA APARECIDA DE SOUZA
#
#                                                    NOME_PREPOSTO  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                                           JANA FONSECA VIEIRA
# 84                                    KARINA RODRIGUES BRANDORFI
# 85                            BARBARA ISABELLE CARVALHO DE PAULA
# 86                                   GISELE PAGANO NEVES SALAZAR
# 87                                          EDSON PIRES DE SOUZA
#
#                                       NOME_SETOR  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                                       Criança
# 84                                   Bijouterias
# 85                            Vestuário Infantil
# 86                            Vestuário Infantil
# 87                                     Vestuário
#
#                                                                        PRODUTOS  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                            BOLSA DE BEBÊ, MALA DE MATERNIDADE, NECESSÁIRE...
# 84                                          BRINCO, ANEL, PULSEIRA, COLAR, ARCO
# 85                                                   VESTIDO, CONJUNTO, MACACÃO
# 86                                                    MACACÃO, BLUSA, SAPATINHO
# 87                            BLUSA, BERMUDA, ROUPA DE GINÁSTICA, SAIA, VEST...
#
#                               NUMERO_PRODUTOS_CADASTRADOS       AREA  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                                                    5.0  11.838911
# 84                                                    5.0  11.838911
# 85                                                    3.0  11.838911
# 86                                                    3.0  11.827592
# 87                                                    7.0  11.827592
#
#                               DENSIDADE
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                             0.422336
# 84                             0.422336
# 85                             0.253402
# 86                             0.253644
# 87                             0.591836

# %%
df = df.assign(
    PRODUTOSX2 = produtos * area
)
df
# Out:
#                              CODIGO_VAGA  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                             F.F2.V016
# 84                             G.F3.V052
# 85                             E.F4.V003
# 86                             E.F2.V004
# 87                             D.F2.V016
# ...                                  ...
# 1350                           G.F4.V014
# 1351                           J.F1.V004
# 1352                           D.F4.V050
# 1353                           G.F2.V010
# 1354                           G.F1.V061
#
#                                                            NOME_FANTASIA  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                              BARRACA CARMEN EMMANUEL DOS SANTOS SILVA
# 84                            BARRACA CARMEN FERNANDA ROCHA DE ALCANTARA
# 85                              BARRACA CARMEN LÚCIA CARVALHO DE ALMEIDA
# 86                                  BARRACA CECÍLIA PAGANO NEVES SALAZAR
# 87                                      BARRACA CÉLIA APARECIDA DE SOUZA
# ...                                                                  ...
# 1350                                          BARRACA HELCIO LICIO SILVA
# 1351                                       BARRACA DIEGO DOS SANTOS DIAS
# 1352                                                 BARRACA JAIR CORREA
# 1353                               BARRACA SIDNEY FERNANDO KNEIPP SOARES
# 1354                                      BARRACA REGINA GARCIA FERREIRA
#
#                                                    NOME_FEIRANTE  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                              CARMEN EMMANUEL DOS SANTOS SILVA
# 84                            CARMEN FERNANDA ROCHA DE ALCANTARA
# 85                              CARMEN LÚCIA CARVALHO DE ALMEIDA
# 86                                  CECÍLIA PAGANO NEVES SALAZAR
# 87                                      CÉLIA APARECIDA DE SOUZA
# ...                                                          ...
# 1350                                          HELCIO LICIO SILVA
# 1351                                       DIEGO DOS SANTOS DIAS
# 1352                                                 JAIR CORREA
# 1353                               SIDNEY FERNANDO KNEIPP SOARES
# 1354                                      REGINA GARCIA FERREIRA
#
#                                                    NOME_PREPOSTO  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                                           JANA FONSECA VIEIRA
# 84                                    KARINA RODRIGUES BRANDORFI
# 85                            BARBARA ISABELLE CARVALHO DE PAULA
# 86                                   GISELE PAGANO NEVES SALAZAR
# 87                                          EDSON PIRES DE SOUZA
# ...                                                          ...
# 1350                             GRAZIELA CRISTINA RAMALHO SILVA
# 1351                                     CELSO DE SOUZA LINHARES
# 1352                               Keli Aparecida Batista Correa
# 1353                                 ANA PAULA FAUSTINA DE SOUZA
# 1354                             Rejane Garcia Ferreira Clemente
#
#                                       NOME_SETOR  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                                       Criança
# 84                                   Bijouterias
# 85                            Vestuário Infantil
# 86                            Vestuário Infantil
# 87                                     Vestuário
# ...                                          ...
# 1350                                 Bijouterias
# 1351                                    Calçados
# 1352                                   Vestuário
# 1353                                 Bijouterias
# 1354                                 Bijouterias
#
#                                                                        PRODUTOS  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                            BOLSA DE BEBÊ, MALA DE MATERNIDADE, NECESSÁIRE...
# 84                                          BRINCO, ANEL, PULSEIRA, COLAR, ARCO
# 85                                                   VESTIDO, CONJUNTO, MACACÃO
# 86                                                    MACACÃO, BLUSA, SAPATINHO
# 87                            BLUSA, BERMUDA, ROUPA DE GINÁSTICA, SAIA, VEST...
# ...                                                                         ...
# 1350                          ANEL, COLAR, BROCHE, BRINCO, PULSEIRA, ALIANÇA...
# 1351                                              RASTEIRINHA, SAPATO, SANDÁLIA
# 1352                          VESTIDO DE MALHA, BATA DE TECIDO, CONJUNTO, SA...
# 1353                          COLAR, GARGANTILHA, ARCO, ANEL, PASSADOR DE CA...
# 1354                          COLAR DE METAL, PRESILHA, PASSADOR DE CABELO, ...
#
#                               NUMERO_PRODUTOS_CADASTRADOS       AREA  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                                                    5.0  11.838911
# 84                                                    5.0  11.838911
# 85                                                    3.0  11.838911
# 86                                                    3.0  11.827592
# 87                                                    7.0  11.827592
# ...                                                   ...        ...
# 1350                                                  7.0  11.838911
# 1351                                                  3.0  11.827592
# 1352                                                  5.0  11.827592
# 1353                                                  7.0  11.838911
# 1354                                                  4.0  11.827592
#
#                               DENSIDADE  PRODUTOSX2
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                             0.422336   47.355645
# 84                             0.422336   23.655184
# 85                             0.253402   35.482777
# 86                             0.253644   35.516733
# 87                             0.591836   47.355645
# ...                                 ...         ...
# 1350                           0.591271         NaN
# 1351                           0.253644         NaN
# 1352                           0.422740         NaN
# 1353                           0.591271         NaN
# 1354                           0.338192         NaN
#
# [1250 rows x 10 columns]

# %%
df.head()
# Out:
#                              CODIGO_VAGA  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                             F.F2.V016
# 84                             G.F3.V052
# 85                             E.F4.V003
# 86                             E.F2.V004
# 87                             D.F2.V016
#
#                                                            NOME_FANTASIA  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                              BARRACA CARMEN EMMANUEL DOS SANTOS SILVA
# 84                            BARRACA CARMEN FERNANDA ROCHA DE ALCANTARA
# 85                              BARRACA CARMEN LÚCIA CARVALHO DE ALMEIDA
# 86                                  BARRACA CECÍLIA PAGANO NEVES SALAZAR
# 87                                      BARRACA CÉLIA APARECIDA DE SOUZA
#
#                                                    NOME_FEIRANTE  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                              CARMEN EMMANUEL DOS SANTOS SILVA
# 84                            CARMEN FERNANDA ROCHA DE ALCANTARA
# 85                              CARMEN LÚCIA CARVALHO DE ALMEIDA
# 86                                  CECÍLIA PAGANO NEVES SALAZAR
# 87                                      CÉLIA APARECIDA DE SOUZA
#
#                                                    NOME_PREPOSTO  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                                           JANA FONSECA VIEIRA
# 84                                    KARINA RODRIGUES BRANDORFI
# 85                            BARBARA ISABELLE CARVALHO DE PAULA
# 86                                   GISELE PAGANO NEVES SALAZAR
# 87                                          EDSON PIRES DE SOUZA
#
#                                       NOME_SETOR  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                                       Criança
# 84                                   Bijouterias
# 85                            Vestuário Infantil
# 86                            Vestuário Infantil
# 87                                     Vestuário
#
#                                                                        PRODUTOS  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                            BOLSA DE BEBÊ, MALA DE MATERNIDADE, NECESSÁIRE...
# 84                                          BRINCO, ANEL, PULSEIRA, COLAR, ARCO
# 85                                                   VESTIDO, CONJUNTO, MACACÃO
# 86                                                    MACACÃO, BLUSA, SAPATINHO
# 87                            BLUSA, BERMUDA, ROUPA DE GINÁSTICA, SAIA, VEST...
#
#                               NUMERO_PRODUTOS_CADASTRADOS       AREA  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                                                    5.0  11.838911
# 84                                                    5.0  11.838911
# 85                                                    3.0  11.838911
# 86                                                    3.0  11.827592
# 87                                                    7.0  11.827592
#
#                               DENSIDADE  PRODUTOSX2
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                             0.422336   47.355645
# 84                             0.422336   23.655184
# 85                             0.253402   35.482777
# 86                             0.253644   35.516733
# 87                             0.591836   47.355645

# %% [markdown]
# ## Recapitulação: consultas

# %% [markdown]
# ### O que é uma consulta? 🤔
#
# - Uma "consulta" é um código que extrai linhas de um DataFrame para as quais determinadas condições são verdadeiras.
# - Freqüentemente usamos consultas para _filtrar_ DataFrames para que contenham apenas as linhas que satisfaçam as condições declaradas em nossas perguntas.

# %% [markdown]
# ### Como consultamos um DataFrame?
#
# Para selecionar apenas determinadas linhas do DataFrame `df`:
#
# 1. Faça uma sequência (lista/array/Série) de `True`s (manter) e `False`s (jogar fora), geralmente fazendo uma comparação.
# 2. Em seguida, passe-o para `df[consulta]`.

# %% [markdown]
# ### Comparações entre elementos
#
# Existem vários tipos de comparações que podemos fazer.
#
# |símbolo|significado|
# |--------|--------|
# |`==` |igual a |
# |`!=` |diferente de |
# |`<`|menos que|
# |`<=`|menor ou igual a|
# |`>`|maior que|
# |`>=`|maior ou igual a|

# %% [markdown]
# ## Exemplo 5: Qual o número de barracas de comida?
#
# **Conceito principal**: consulta

# %% [markdown]
# ### Estratégia
#
# 1. Consulta para extrair um DataFrame apenas das solicitações `'Alimentação'`.
# 2. Classifique por `'NUMERO_PRODUTOS_CADASTRADOS'` em ordem decrescente.
# 3. Extraia o primeiro elemento da coluna `'NOME_FEIRANTE'`.

# %%
#comida = df[df.get('NOME_SETOR') == 'Alimentação']
#comida.shape
# Out:
# (100, 10)

# %%
barracasComida = df[df.get('NOME_SETOR') == 'Alimentação']
barracasComida
# Out:
#                              CODIGO_VAGA  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 92                             Y.F1.V003
# 109                            Y.F1.V012
# 116                            Z.F4.V001
# 231                            Y.F1.V026
# 261                            X.F2.V003
# ...                                  ...
# 1454                           Y.F1.V002
# 1457                           X.F2.V011
# 1423                           X.F1.V003
# 1335                           Z.F2.V004
# 1346                           Y.F2.V004
#
#                                                           NOME_FANTASIA  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 92                                 BARRACA CHAQUIBE HASSAN SOUKI HUNIOR
# 109                                        BARRACA DAYSE PINTO NORBERTO
# 116                                        BARRACA DILSON ALVES DE DEUS
# 231                                     BARRACA IRENE FERREIRA DE FARIA
# 261                               BARRACA JOÃO GERALDO MARTINS DE SOUZA
# ...                                                                 ...
# 1454                             BARRACA ISAURA MARIA MEDEIROS DA SILVA
# 1457                                   BARRACA WELLINGTON ALVES DE DEUS
# 1423                          BARRACA CELIA APARECIDA MONTEIRO CIPRIANO
# 1335                                       BARRACA WILSON RENATO COELHO
# 1346                                    BARRACA VÂNIA LÚCIA ALVES MARIA
#
#                                                   NOME_FEIRANTE  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 92                                 CHAQUIBE HASSAN SOUKI HUNIOR
# 109                                        DAYSE PINTO NORBERTO
# 116                                        DILSON ALVES DE DEUS
# 231                                     IRENE FERREIRA DE FARIA
# 261                               JOÃO GERALDO MARTINS DE SOUZA
# ...                                                         ...
# 1454                             ISAURA MARIA MEDEIROS DA SILVA
# 1457                                   WELLINGTON ALVES DE DEUS
# 1423                          CELIA APARECIDA MONTEIRO CIPRIANO
# 1335                                       WILSON RENATO COELHO
# 1346                                    VÂNIA LÚCIA ALVES MARIA
#
#                                                    NOME_PREPOSTO   NOME_SETOR  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 92                                             GISMAR JOSÉ GOMES  Alimentação
# 109                                    DJALMA ANTÔNIO DE FREITAS  Alimentação
# 116                                       EVALDO RODRIGUES PINTO  Alimentação
# 231                             DANIELA CINTIA FERREIRA DE SOUZA  Alimentação
# 261                                CHARLES DAVIDSON ROSA MARTINS  Alimentação
# ...                                                          ...          ...
# 1454                                  LUCIENE RODRIGUES JANUARIO  Alimentação
# 1457                                        SANDRO ALVES DE DEUS  Alimentação
# 1423                                   APARECIDA SANTOS MONTEIRO  Alimentação
# 1335                            LIDIANE DE CASTRO SILVA DORNELES  Alimentação
# 1346                          VANESSA LÚCIA ALVES MARIA CARVALHO  Alimentação
#
#                                                                        PRODUTOS  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 92                                                                 DOCE DIVERSO
# 109                           CERVEJA, TORRESMO, CHIPS, AZEITONA, REFRIGERAN...
# 116                           CHURRASCO, ÁGUA MINERAL, SANDUÍCHE DE PERNIL, ...
# 231                           CHURRASCO, SUCO INDUSTRIALIZADO, ÁGUA MINERAL,...
# 261                                                                   CHURRASCO
# ...                                                                         ...
# 1454                          MILHO VERDE, REFRIGERANTE, PAMONHA, MINGAU DE ...
# 1457                                                                  CHURRASCO
# 1423                                                                    ACARAJÉ
# 1335                          CERVEJA, QUEIJOS, AZEITONA, SALAMINHO, REFRIGE...
# 1346                          CHURRASCO, REFRIGERANTE, CERVEJA, SUCO INDUSTR...
#
#                               NUMERO_PRODUTOS_CADASTRADOS       AREA  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 92                                                    1.0  33.605972
# 109                                                  21.0  33.611057
# 116                                                   7.0  33.591701
# 231                                                   5.0  33.534286
# 261                                                   1.0  33.569063
# ...                                                   ...        ...
# 1454                                                 13.0  33.572508
# 1457                                                  1.0  33.595966
# 1423                                                  1.0  33.697508
# 1335                                                  8.0  33.611058
# 1346                                                  4.0  33.539371
#
#                               DENSIDADE  PRODUTOSX2
# ID_FEIRA_AFONSO_PENA_BARRACA
# 92                             0.029757   35.516733
# 109                            0.624794   23.677822
# 116                            0.208385   47.355645
# 231                            0.149101   84.822837
# 261                            0.029789  169.645675
# ...                                 ...         ...
# 1454                           0.387222         NaN
# 1457                           0.029765         NaN
# 1423                           0.029676         NaN
# 1335                           0.238017         NaN
# 1346                           0.119263         NaN
#
# [100 rows x 10 columns]

# %% [markdown]
# ### Qual o (**A PESSOA**) feirante que vende mais produtos de comida?

# %%
barracasComida = barracasComida.sort_values(by='NUMERO_PRODUTOS_CADASTRADOS', ascending=False)
barracasComida
# Out:
#                              CODIGO_VAGA  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 109                            Y.F1.V012
# 1406                           Z.F1.V007
# 1015                           X.F1.V020
# 380                            Y.F1.V020
# 26                             Y.F2.V007
# ...                                  ...
# 1269                           X.F2.V013
# 545                            Y.F1.V027
# 1423                           X.F1.V003
# 1457                           X.F2.V011
# 92                             Y.F1.V003
#
#                                                                   NOME_FANTASIA  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 109                                                BARRACA DAYSE PINTO NORBERTO
# 1406                          BARRACA FRANCINERE AMARAL CARDOSO RIBEIRO DE S...
# 1015                                      BARRACA VERA LUIZA DE CARVALHO MACEDO
# 380                                       BARRACA MARGARET LÚCIA DA COSTA SILVA
# 26                                                   BARRACA ANA CALDEIRA GOMES
# ...                                                                         ...
# 1269                                     BARRACA FELIPE RODRIGUES ALVES DE DEUS
# 545                                       BARRACA NATALICE BARBOSA DA CONCEIÇÃO
# 1423                                  BARRACA CELIA APARECIDA MONTEIRO CIPRIANO
# 1457                                           BARRACA WELLINGTON ALVES DE DEUS
# 92                                         BARRACA CHAQUIBE HASSAN SOUKI HUNIOR
#
#                                                            NOME_FEIRANTE  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 109                                                 DAYSE PINTO NORBERTO
# 1406                          FRANCINERE AMARAL CARDOSO RIBEIRO DE SOUZA
# 1015                                       VERA LUIZA DE CARVALHO MACEDO
# 380                                        MARGARET LÚCIA DA COSTA SILVA
# 26                                                    ANA CALDEIRA GOMES
# ...                                                                  ...
# 1269                                      FELIPE RODRIGUES ALVES DE DEUS
# 545                                        NATALICE BARBOSA DA CONCEIÇÃO
# 1423                                   CELIA APARECIDA MONTEIRO CIPRIANO
# 1457                                            WELLINGTON ALVES DE DEUS
# 92                                          CHAQUIBE HASSAN SOUKI HUNIOR
#
#                                                  NOME_PREPOSTO   NOME_SETOR  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 109                                  DJALMA ANTÔNIO DE FREITAS  Alimentação
# 1406                                   RAYKARD AGUIAR DE JESUS  Alimentação
# 1015                                         ORLANDINEIA ALVES  Alimentação
# 380                            MARIA TRINDADE DECIOLA DE JESUS  Alimentação
# 26                            PAULO HENRIQUE DE JESUS CALDEIRA  Alimentação
# ...                                                        ...          ...
# 1269                                      SIDNEY ALVES DE DEUS  Alimentação
# 545                                    WALDIR BARBOSA DA SILVA  Alimentação
# 1423                                 APARECIDA SANTOS MONTEIRO  Alimentação
# 1457                                      SANDRO ALVES DE DEUS  Alimentação
# 92                                           GISMAR JOSÉ GOMES  Alimentação
#
#                                                                        PRODUTOS  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 109                           CERVEJA, TORRESMO, CHIPS, AZEITONA, REFRIGERAN...
# 1406                          CERVEJA, REFRIGERANTE, SUCO INDUSTRIALIZADO, E...
# 1015                          CERVEJA, SANDUÍCHE NATURAL, BISCOITO, BOLO, RO...
# 380                           ACARAJÉ, BOLINHO DE CARNE DE SOL, SUCO DE AÇAÍ...
# 26                            CHURRASCO, PÃO DE QUEIJO, LEITE, REFRIGERANTE,...
# ...                                                                         ...
# 1269                                                                  CHURRASCO
# 545                                                                     ACARAJÉ
# 1423                                                                    ACARAJÉ
# 1457                                                                  CHURRASCO
# 92                                                                 DOCE DIVERSO
#
#                               NUMERO_PRODUTOS_CADASTRADOS       AREA  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 109                                                  21.0  33.611057
# 1406                                                 20.0  33.611058
# 1015                                                 17.0  33.595966
# 380                                                  16.0  33.539371
# 26                                                   14.0  33.611058
# ...                                                   ...        ...
# 1269                                                  1.0  33.558728
# 545                                                   1.0  33.611058
# 1423                                                  1.0  33.697508
# 1457                                                  1.0  33.595966
# 92                                                    1.0  33.605972
#
#                               DENSIDADE  PRODUTOSX2
# ID_FEIRA_AFONSO_PENA_BARRACA
# 109                            0.624794   23.677822
# 1406                           0.595042         NaN
# 1015                           0.506013   59.137961
# 380                            0.477051   47.310369
# 26                             0.416530   82.793146
# ...                                 ...         ...
# 1269                           0.029799         NaN
# 545                            0.029752  141.931107
# 1423                           0.029676         NaN
# 1457                           0.029765         NaN
# 92                             0.029757   35.516733
#
# [100 rows x 10 columns]

# %%
#comida = comida.sort_values(by='NUMERO_PRODUTOS_CADASTRADOS', ascending=False)
#comida

# %%
# iloc pega a n-ésimo linha. não busca por índice, sim por linha
# comida.get('NOME_FEIRANTE').iloc[0]
barracasComida.get('NOME_FEIRANTE').iloc[10]
# Out:
# 'ISAURA MARIA MEDEIROS DA SILVA'

# %% [markdown]
# ### E se a condição não for satisfeita?

# %%
df[df.get('NOME_FEIRANTE') == 'FLAVIO FIGUEIREDO']
# Out:
# Empty DataFrame
# Columns: [CODIGO_VAGA, NOME_FANTASIA, NOME_FEIRANTE, NOME_PREPOSTO, NOME_SETOR, PRODUTOS, NUMERO_PRODUTOS_CADASTRADOS, AREA, DENSIDADE, PRODUTOSX2]
# Index: []

# %%
df[df.get('NOME_FEIRANTE') == 'ISAURA MARIA MEDEIROS DA SILVA']
# Out:
#                              CODIGO_VAGA  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 1454                           Y.F1.V002
#
#                                                        NOME_FANTASIA  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 1454                          BARRACA ISAURA MARIA MEDEIROS DA SILVA
#
#                                                NOME_FEIRANTE  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 1454                          ISAURA MARIA MEDEIROS DA SILVA
#
#                                            NOME_PREPOSTO   NOME_SETOR  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 1454                          LUCIENE RODRIGUES JANUARIO  Alimentação
#
#                                                                        PRODUTOS  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 1454                          MILHO VERDE, REFRIGERANTE, PAMONHA, MINGAU DE ...
#
#                               NUMERO_PRODUTOS_CADASTRADOS       AREA  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 1454                                                 13.0  33.572508
#
#                               DENSIDADE  PRODUTOSX2
# ID_FEIRA_AFONSO_PENA_BARRACA
# 1454                           0.387222         NaN

# %% [markdown]
# ### Verificação de conceito ✅
#
# Qual expressão abaixo é avaliada como **o número total de produtos infantis**?
#
# A. `df[df.get('NOME_SETOR') == 'Criança'].shape`
#
# B. `df[df.get('NOME_SETOR') == 'Criança'].get('NUMERO_PRODUTOS_CADASTRADOS').sum()`
#
# C.`df[df.get('NOME_SETOR') != 'Criança'].get('NUMERO_PRODUTOS_CADASTRADOS').sum()`
#
# D. Mais de um dos itens acima.

# %%
df[df.get('NOME_SETOR') == 'Criança'].get('NUMERO_PRODUTOS_CADASTRADOS').sum()
# Out:
# 758.0

# %% [markdown]
# ### Atividade 🚘
#
# **Pergunta**: Quais são os produtos vendidos pelo feirante que mais vende produtos infantis?
#
# Escreva uma linha de código que avalie a resposta.

# %%
setorInfantil = df[df['NOME_SETOR'] == 'Criança']
ranking = setorInfantil.groupby('NOME_FEIRANTE')['NUMERO_PRODUTOS_CADASTRADOS'].sum()
ranking = ranking.sort_values(ascending=False)
nomeMaiorVendedorInfantil = ranking.idxmax()
quantMaiorVendedorInfantil = ranking.max()
prodMaiorVendedorInfantil = df[df['NOME_FEIRANTE'] == nomeMaiorVendedorInfantil]['PRODUTOS'].unique()
prodFormatados = ", ".join(prodMaiorVendedorInfantil)
print(f"Maior vendedor: {nomeMaiorVendedorInfantil}\nQunatidade Produtos Vendidos: {quantMaiorVendedorInfantil}\nProdutos Vendidos: {prodFormatados}")
# Out:
# Maior vendedor: MARILEA IMACULADA MUNIZ COSTA
# Qunatidade Produtos Vendidos: 21.0
# Produtos Vendidos: KIT BERÇO, CORTINADO, BONECA DE PELÚCIA, SAIA PARA BERÇO, CAPA DE BEBÊ CONFORTO, CAPA DE CARRINHO, MANTA, VIROL, FRONHA, CABIDE, EDREDON, TRAVESSEIRO, ALMOFADA DE AMAMENTAÇÃO, TOALHA, BABINHA, PORTA BEBÊ, ROLO, TROCADOR, SEGURA BEBÊ, SACO DE BEBÊ, CORTINA

# %% [markdown]
# ## Exemplo 6: Quantos feirantes vendem Vestuário Infantil e Produtos Infantis?
#
# **Conceito principal**: Consultas com múltiplas condições.

# %% [markdown]
# ### Múltiplas condições
#
# - Para escrever uma consulta com múltiplas condições, use `&` para "e" e `|` para "ou".
# - **Você deve usar `(`parênteses`)` em torno de cada condição!**
# - ⚠️ Não use as palavras-chave Python `and` e `or` aqui! Eles não se comportam como você gostaria.
# - Consulte [BPD 10.3](https://notes.dsc10.com/02-data_sets/querying.html#multiple-conditions) para obter uma explicação.

# %%
#df[(df.get('NOME_SETOR') == 'Vestuário Infantil') | (df.get('NOME_SETOR') == 'Criança')]
df[(df.get('NOME_SETOR') == 'Vestuario Infantil') | (df.get('NOME_SETOR') == 'Criança')]
# Out:
#                              CODIGO_VAGA  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                             F.F2.V016
# 97                             F.F3.V022
# 99                             F.F2.V002
# 108                            F.F1.V031
# 114                            F.F2.V013
# ...                                  ...
# 1411                           F.F3.V013
# 1467                           F.F1.V005
# 1468                           F.F4.V014
# 1426                           F.F3.V010
# 1337                           F.F2.V004
#
#                                                          NOME_FANTASIA  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                            BARRACA CARMEN EMMANUEL DOS SANTOS SILVA
# 97                                 BARRACA CLÁUDIA REGINA RACHID NETTO
# 99                              BARRACA CLESIA LUCI TORRES DE OLIVEIRA
# 108                                              BARRACA DAISY ANDRADE
# 114                                       BARRACA DIRLENE VILELA ROMÃO
# ...                                                                ...
# 1411                               BARRACA ROSANA DANIEL DE FIGUEIREDO
# 1467                                  BARRACA LYDNEIA MELISSA TEIXEIRA
# 1468                           BARRACA PAULA GUERRA IGLESIAS RODRIGUES
# 1426                                  BARRACA ALESSANDRA DE ABREU REIS
# 1337                             BARRACA MATHEUS PESSALI TIAGO BARBOSA
#
#                                                  NOME_FEIRANTE  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                            CARMEN EMMANUEL DOS SANTOS SILVA
# 97                                 CLÁUDIA REGINA RACHID NETTO
# 99                              CLESIA LUCI TORRES DE OLIVEIRA
# 108                                              DAISY ANDRADE
# 114                                       DIRLENE VILELA ROMÃO
# ...                                                        ...
# 1411                               ROSANA DANIEL DE FIGUEIREDO
# 1467                                  LYDNEIA MELISSA TEIXEIRA
# 1468                           PAULA GUERRA IGLESIAS RODRIGUES
# 1426                                  ALESSANDRA DE ABREU REIS
# 1337                             MATHEUS PESSALI TIAGO BARBOSA
#
#                                                   NOME_PREPOSTO NOME_SETOR  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                                          JANA FONSECA VIEIRA    Criança
# 97                                   HERMOGENES GONÇALVES NETTO    Criança
# 99                                ANA CAROLINE SILVA MATOZINHOS    Criança
# 108                                              MARCIO MARTINS    Criança
# 114                                       MICHELLE VILELA COSTA    Criança
# ...                                                         ...        ...
# 1411                             MARIA DO ROSARIO SILVA SALGADO    Criança
# 1467                          LYDSSEI MELISSA TEIXEIRA FERREIRA    Criança
# 1468                                GREG PETERSON LOPES PERUZZO    Criança
# 1426                            GLAUCIA HELENA DE ABREU TAVARES    Criança
# 1337                                      MIRNA COSTA GONÇALVES    Criança
#
#                                                                        PRODUTOS  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                            BOLSA DE BEBÊ, MALA DE MATERNIDADE, NECESSÁIRE...
# 97                                 SACOLA, MOISÉS, FRASQUEIRA, MALA, NECESSÁIRE
# 99                                                BONECO, MÓBILE, BICHO DE PANO
# 108                                                               PAGÃO, CABIDE
# 114                           EDREDON, MANTA, CAPA DE CARRINHO, CORTINADO DE...
# ...                                                                         ...
# 1411                          KIT BERÇO, MANTA, PROTETOR DE BERÇO, CAPA DE C...
# 1467                          KIT BERÇO, SAIA PARA BERÇO, NINHO, LENÇOL, ALM...
# 1468                          BONECA DE PANO, BONECA DE FELTRO, BONECO, DEDO...
# 1426                          ACESSÓRIOS PARA CACHORRO, ALMOFADA, CAMA DE TE...
# 1337                          QUADRO, TOALHA FRALDA, TOALHA, BRINQUEDO PEDAG...
#
#                               NUMERO_PRODUTOS_CADASTRADOS       AREA  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                                                    5.0  11.838911
# 97                                                    5.0  11.838911
# 99                                                    3.0  11.838911
# 108                                                   2.0  11.827592
# 114                                                   7.0  11.827592
# ...                                                   ...        ...
# 1411                                                 10.0  11.827592
# 1467                                                  8.0  11.827592
# 1468                                                  5.0  11.838911
# 1426                                                 14.0  11.838911
# 1337                                                  6.0  11.838911
#
#                               DENSIDADE  PRODUTOSX2
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                             0.422336   47.355645
# 97                             0.422336   70.965553
# 99                             0.253402   35.482777
# 108                            0.169096   23.790191
# 114                            0.591836  106.550200
# ...                                 ...         ...
# 1411                           0.845481         NaN
# 1467                           0.676384         NaN
# 1468                           0.422336         NaN
# 1426                           1.182541         NaN
# 1337                           0.506803         NaN
#
# [103 rows x 10 columns]

# %%
# Dentro de de parênteses () ou de colchetes [] podemos quebrar a linha. ajuda na leitura
df[(df.get('NOME_SETOR') == 'Vestuário Infantil') |
   (df.get('NOME_SETOR') == 'Criança')]
# Out:
#                              CODIGO_VAGA  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                             F.F2.V016
# 85                             E.F4.V003
# 86                             E.F2.V004
# 88                             E.F3.V016
# 94                             E.F4.V029
# ...                                  ...
# 1426                           F.F3.V010
# 1435                           E.F4.V006
# 1337                           F.F2.V004
# 1342                           E.F1.V005
# 1343                           E.F1.V033
#
#                                                                   NOME_FANTASIA  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                                     BARRACA CARMEN EMMANUEL DOS SANTOS SILVA
# 85                                     BARRACA CARMEN LÚCIA CARVALHO DE ALMEIDA
# 86                                         BARRACA CECÍLIA PAGANO NEVES SALAZAR
# 88                                        BARRACA CELINA MARIA  SILVA MARCELINO
# 94                            BARRACA CLARICE CONCEIÇÃO DAS GRAÇAS DE OLIVEI...
# ...                                                                         ...
# 1426                                           BARRACA ALESSANDRA DE ABREU REIS
# 1435                                              BARRACA CILDA LUZIA GUALBERTO
# 1337                                      BARRACA MATHEUS PESSALI TIAGO BARBOSA
# 1342                                           BARRACA MAIRA FERNANDES DE MOURA
# 1343                                               BARRACA ELIANE CORREA JANSEN
#
#                                                               NOME_FEIRANTE  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                                         CARMEN EMMANUEL DOS SANTOS SILVA
# 85                                         CARMEN LÚCIA CARVALHO DE ALMEIDA
# 86                                             CECÍLIA PAGANO NEVES SALAZAR
# 88                                            CELINA MARIA  SILVA MARCELINO
# 94                            CLARICE CONCEIÇÃO DAS GRAÇAS DE OLIVEIRA LIMA
# ...                                                                     ...
# 1426                                               ALESSANDRA DE ABREU REIS
# 1435                                                  CILDA LUZIA GUALBERTO
# 1337                                          MATHEUS PESSALI TIAGO BARBOSA
# 1342                                               MAIRA FERNANDES DE MOURA
# 1343                                                   ELIANE CORREA JANSEN
#
#                                                    NOME_PREPOSTO  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                                           JANA FONSECA VIEIRA
# 85                            BARBARA ISABELLE CARVALHO DE PAULA
# 86                                   GISELE PAGANO NEVES SALAZAR
# 88                                    ALBERTINO SERGIO MARCELINO
# 94                               ANGELICA MARIA DE OLIVEIRA LIMA
# ...                                                          ...
# 1426                             GLAUCIA HELENA DE ABREU TAVARES
# 1435                           CILMA MARIA GUALBERTO DE OLIVEIRA
# 1337                                       MIRNA COSTA GONÇALVES
# 1342                                   MAURÍCIO MARTINS TERRINHA
# 1343                                        ANDREA CORREA JANSEN
#
#                                       NOME_SETOR  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                                       Criança
# 85                            Vestuário Infantil
# 86                            Vestuário Infantil
# 88                            Vestuário Infantil
# 94                            Vestuário Infantil
# ...                                          ...
# 1426                                     Criança
# 1435                          Vestuário Infantil
# 1337                                     Criança
# 1342                          Vestuário Infantil
# 1343                          Vestuário Infantil
#
#                                                                        PRODUTOS  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                            BOLSA DE BEBÊ, MALA DE MATERNIDADE, NECESSÁIRE...
# 85                                                   VESTIDO, CONJUNTO, MACACÃO
# 86                                                    MACACÃO, BLUSA, SAPATINHO
# 88                              FANTASIA, BERMUDA, CALÇA, SAIA, VESTIDO, CAMISA
# 94                            CONJUNTO, SHORT, CUECA, CAMISA, CAMISETA, BLUS...
# ...                                                                         ...
# 1426                          ACESSÓRIOS PARA CACHORRO, ALMOFADA, CAMA DE TE...
# 1435                               VESTIDO, BOLERO, CUECA, BERMUDA, SAIA, BLUSA
# 1337                          QUADRO, TOALHA FRALDA, TOALHA, BRINQUEDO PEDAG...
# 1342                                    JARDINEIRA, VESTIDO, SHORT, SAIA, BLUSA
# 1343                               VESTIDO, TIARA, BLUSA, BODY, TOUCA, CALCINHA
#
#                               NUMERO_PRODUTOS_CADASTRADOS       AREA  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                                                    5.0  11.838911
# 85                                                    3.0  11.838911
# 86                                                    3.0  11.827592
# 88                                                    6.0  11.827592
# 94                                                    7.0  11.838911
# ...                                                   ...        ...
# 1426                                                 14.0  11.838911
# 1435                                                  6.0  11.827592
# 1337                                                  6.0  11.838911
# 1342                                                  5.0  11.838911
# 1343                                                  6.0  11.838911
#
#                               DENSIDADE  PRODUTOSX2
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                             0.422336   47.355645
# 85                             0.253402   35.482777
# 86                             0.253644   35.516733
# 88                             0.507288   94.620738
# 94                             0.591271   23.655184
# ...                                 ...         ...
# 1426                           1.182541         NaN
# 1435                           0.507288         NaN
# 1337                           0.506803         NaN
# 1342                           0.422336         NaN
# 1343                           0.506803         NaN
#
# [224 rows x 10 columns]

# %% [markdown]
# ### Pergunta Original: Quantos feirante nos dois setores?

# %%
df[(df.get('NOME_SETOR') == 'Vestuário Infantil') |
   (df.get('NOME_SETOR') == 'Criança')].shape[0]
# Out:
# 224

# %%
df.get('NOME_SETOR').unique()
# Out:
# array(['Criança', 'Bijouterias', 'Vestuário Infantil', 'Vestuário',
#        'Calçados', 'Alimentação', 'Cintos, Bolsas e Acessórios',
#        'Artes e Pintura', 'Arranjos e Complementos',
#        'Decoração e Utilidades', 'Cama, Mesa, Banho e Tapeçaria',
#        'Mobilário, Flores, Arranjos, Cestaria', 'Esculturas'],
#       dtype=object)

# %% [markdown]
# ### Verificação de conceito ✅
#
# Cada uma das perguntas a seguir pode ser respondida consultando o DataFrame `requests`.
#
# 1. Qual categoria tem mais produtos, 'Artes e Pintura' ou 'Esculturas'?
# 2. Quantos feirantes vendem 'Vestuário'?
# 3. Qual o nome do feirante que vende mais 'Vestuário'?
# 4. Quantas das perguntas acima **exigem** que a consulta tenha **múltiplas condições**?
#
#
# Tente escrever o código para responder a cada pergunta.

# %%
df.columns
# Out:
# Index(['CODIGO_VAGA', 'NOME_FANTASIA', 'NOME_FEIRANTE', 'NOME_PREPOSTO',
#        'NOME_SETOR', 'PRODUTOS', 'NUMERO_PRODUTOS_CADASTRADOS', 'AREA',
#        'DENSIDADE', 'PRODUTOSX2'],
#       dtype='object')

# %%
#--------------------------------------
#QUESTAO 1

numEsculturas = df[df['NOME_SETOR'] == 'Esculturas']['NUMERO_PRODUTOS_CADASTRADOS'].sum()
numArtes = df[df['NOME_SETOR'] == 'Artes e Pintura']['NUMERO_PRODUTOS_CADASTRADOS'].sum()
if(numEsculturas > numArtes):
    print(f'Há mais esculturas do que artes e pinturas! - Quantidade de Esculturas: {numEsculturas}')
else:
    print(f'Há mais artes e pinturas do que esculturas! - Quantidade de Artes e Pinturas: {numArtes}')

#--------------------------------------
#QUESTAO 2

vendedoresVestuario = df[df['NOME_SETOR'] == 'Vestuário']['NOME_FEIRANTE'].nunique()
print(f'Quantidade de vendedores de Vestuário: {vendedoresVestuario}')

#--------------------------------------
#QUESTAO 3 

vestuario = df[df['NOME_SETOR'] == 'Vestuário']
rankVestuario = vestuario.groupby('NOME_FEIRANTE')['NUMERO_PRODUTOS_CADASTRADOS'].sum()
maiorVendVestu = rankVestuario.idxmax()
quantMaiorVendedorVestuario = rankVestuario.max()
print(f'O maior vendedor da categoria de vestuários é o {maiorVendVestu} que vende {quantMaiorVendedorVestuario} tipos de vestuarios')

#--------------------------------------
#QUESTAO 4

#Qual é o nome do feirante que vende "Esculturas" ou "Artes e Pintura", tem área maior que 12, e cuja densidade seja maior que 0.6?
#Mostre também quantos produtos ele tem cadastrados.

setoresCondicao = (df['NOME_SETOR'] == 'Esculturas') | (df['NOME_SETOR'] == 'Artes e Pintura')
areaCondicao = (df['AREA'] > 5) & (df['DENSIDADE'] > 0.1)
filtro = setoresCondicao & areaCondicao
feiranteCondicao = df[filtro]
rankF = feiranteCondicao.groupby('NOME_FEIRANTE')['NUMERO_PRODUTOS_CADASTRADOS'].sum()
maiorCond = rankF.idxmax()
quantCond = rankF.max()
print(f'O feirante que atende as condições é o {maiorCond}, que possue {quantCond} produtos cadastrados.')
# Out:
# Há mais artes e pinturas do que esculturas! - Quantidade de Artes e Pinturas: 62.0
# Quantidade de vendedores de Vestuário: 218
# O maior vendedor da categoria de vestuários é o ISAC FERREIRA REIS que vende 12.0 tipos de vestuarios
# O feirante que atende as condições é o JANE APARECIDA XAVIER DIAS, que possue 5.0 produtos cadastrados.

# %% [markdown]
# ### Selecionando linhas por posição com `.take`
#
# - A consulta nos permite selecionar linhas que satisfaçam uma determinada _condição_.
# - Também podemos selecionar linhas em _posições_ específicas com `.take([list_of_integer_positions])`. Isso mantém apenas as linhas cujas posições estão na lista especificada.
# - Isso é análogo a usar `.iloc[]` em uma série.
# - É raro precisar selecionar linhas por posição inteira. Consultar é **muito** mais útil.

# %%
posicoesDesejadas = [1,3,25]
df.take(posicoesDesejadas)
# Out:
#                              CODIGO_VAGA  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 84                             G.F3.V052
# 86                             E.F2.V004
# 113                            G.F4.V017
#
#                                                                  NOME_FANTASIA  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 84                                  BARRACA CARMEN FERNANDA ROCHA DE ALCANTARA
# 86                                        BARRACA CECÍLIA PAGANO NEVES SALAZAR
# 113                           BARRACA DIANE CRISTINA GONÇALVES MENDONÇA BASTOS
#
#                                                          NOME_FEIRANTE  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 84                                  CARMEN FERNANDA ROCHA DE ALCANTARA
# 86                                        CECÍLIA PAGANO NEVES SALAZAR
# 113                           DIANE CRISTINA GONÇALVES MENDONÇA BASTOS
#
#                                              NOME_PREPOSTO  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 84                              KARINA RODRIGUES BRANDORFI
# 86                             GISELE PAGANO NEVES SALAZAR
# 113                           LUIS RICARDO MENDONÇA BASTOS
#
#                                       NOME_SETOR  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 84                                   Bijouterias
# 86                            Vestuário Infantil
# 113                                  Bijouterias
#
#                                                                        PRODUTOS  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 84                                          BRINCO, ANEL, PULSEIRA, COLAR, ARCO
# 86                                                    MACACÃO, BLUSA, SAPATINHO
# 113                           BRINCO, COLAR, ANEL, BROCHE, ARCO, PASSADOR DE...
#
#                               NUMERO_PRODUTOS_CADASTRADOS       AREA  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 84                                                    5.0  11.838911
# 86                                                    3.0  11.827592
# 113                                                   8.0  11.827592
#
#                               DENSIDADE  PRODUTOSX2
# ID_FEIRA_AFONSO_PENA_BARRACA
# 84                             0.422336   23.655184
# 86                             0.253644   35.516733
# 113                            0.676384   63.617128

# %%
df.take(np.arange(3))
# Out:
#                              CODIGO_VAGA  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                             F.F2.V016
# 84                             G.F3.V052
# 85                             E.F4.V003
#
#                                                            NOME_FANTASIA  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                              BARRACA CARMEN EMMANUEL DOS SANTOS SILVA
# 84                            BARRACA CARMEN FERNANDA ROCHA DE ALCANTARA
# 85                              BARRACA CARMEN LÚCIA CARVALHO DE ALMEIDA
#
#                                                    NOME_FEIRANTE  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                              CARMEN EMMANUEL DOS SANTOS SILVA
# 84                            CARMEN FERNANDA ROCHA DE ALCANTARA
# 85                              CARMEN LÚCIA CARVALHO DE ALMEIDA
#
#                                                    NOME_PREPOSTO  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                                           JANA FONSECA VIEIRA
# 84                                    KARINA RODRIGUES BRANDORFI
# 85                            BARBARA ISABELLE CARVALHO DE PAULA
#
#                                       NOME_SETOR  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                                       Criança
# 84                                   Bijouterias
# 85                            Vestuário Infantil
#
#                                                                        PRODUTOS  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                            BOLSA DE BEBÊ, MALA DE MATERNIDADE, NECESSÁIRE...
# 84                                          BRINCO, ANEL, PULSEIRA, COLAR, ARCO
# 85                                                   VESTIDO, CONJUNTO, MACACÃO
#
#                               NUMERO_PRODUTOS_CADASTRADOS       AREA  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                                                    5.0  11.838911
# 84                                                    5.0  11.838911
# 85                                                    3.0  11.838911
#
#                               DENSIDADE  PRODUTOSX2
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                             0.422336   47.355645
# 84                             0.422336   23.655184
# 85                             0.253402   35.482777

# %% [markdown]
# ## Exemplo 7: Qual é área todal de cada setor?
#
# **Conceito chave**: Agrupamento por uma coluna.

# %% [markdown]
# ### Organizando solicitações por bairro
#
# - Podemos encontrar o número total da área por setor;
# - Por exemplo, `df[df.get('NOME_SETOR') == 'Criança'].get('AREA').sum()`.
# - Mas como podemos encontrar o total para **todos** os setores ao mesmo tempo?

# %%
df[df.get('NOME_SETOR') == 'Criança'].get('AREA').sum()
# Out:
# 1274.9974161428677

# %%
df[df.get('NOME_SETOR') == 'Vestuário Infantil'].get('AREA').sum()
# Out:
# 1431.87438966735

# %% [markdown]
# Parece que tem que haver uma maneira melhor. E aqui está!

# %% [markdown]
# ### GroupBy: dividir, agregar e combinar
#
# Observe o que acontece quando usamos o método `.groupby` em `requests` com o argumento `'neighborhood'`.

# %%
df.groupby('NOME_SETOR').sum()
# Out:
#                                                                              CODIGO_VAGA  \
# NOME_SETOR
# Alimentação                            Y.F1.V003Y.F1.V012Z.F4.V001Y.F1.V026X.F2.V003X...
# Arranjos e Complementos                H.F2.V004H.F2.V005H.F2.V030H.F2.V029H.F1.V014H...
# Artes e Pintura                        P.F1.V014P.F1.V017P.F1.V021P.F1.V020P.F1.V012P...
# Bijouterias                            G.F3.V052G.F3.V035G.F1.V004G.F2.V029G.F2.V012G...
# Calçados                               J.F2.V046J.F4.V035J.F1.V050J.F2.V042J.F3.V025J...
# Cama, Mesa, Banho e Tapeçaria          C.F4.V004C.F4.V015C.F1.V002C.F3.V002C.F1.V003C...
# Cintos, Bolsas e Acessórios            I.F2.V036I.F1.V026I.F4.V012I.F3.V042I.F2.V022I...
# Criança                                F.F2.V016F.F3.V022F.F2.V002F.F1.V031F.F2.V013F...
# Decoração e Utilidades                 B.F1.V018B.F4.V020B.F1.V004B.F2.V016B.F1.V008B...
# Esculturas                                                            S.F1.V002S.F1.V003
# Mobilário, Flores, Arranjos, Cestaria  A.F3.V008A.F1.V004A.F4.V012A.F4.V019A.F1.V006A...
# Vestuário                              D.F2.V016D.F2.V003D.F2.V050D.F1.V036D.F4.V058D...
# Vestuário Infantil                     E.F4.V003E.F2.V004E.F3.V016E.F4.V029E.F3.V008E...
#
#                                                                            NOME_FANTASIA  \
# NOME_SETOR
# Alimentação                            BARRACA CHAQUIBE HASSAN SOUKI HUNIORBARRACA DA...
# Arranjos e Complementos                BARRACA DOMINGOS SÁVIO PEREIRA CARDOSOBARRACA ...
# Artes e Pintura                        BARRACA CONCEIÇÃO APARECIDA MARTINS DE OLIVEIR...
# Bijouterias                            BARRACA CARMEN FERNANDA ROCHA DE ALCANTARABARR...
# Calçados                               BARRACA CENIRA CÂNDIDA DA SILVABARRACA DAVIDSO...
# Cama, Mesa, Banho e Tapeçaria          BARRACA INEZ DE FREITAS NOGUEIRA MIRANDABARRAC...
# Cintos, Bolsas e Acessórios            BARRACA CLÁUDIA MARIA MACHADOBARRACA DILEIA DE...
# Criança                                BARRACA CARMEN EMMANUEL DOS SANTOS SILVABARRAC...
# Decoração e Utilidades                 BARRACA ILMA FERNANDES DE CARVALHO SILVABARRAC...
# Esculturas                             BARRACA JOSÉ RODRIGUES EVANGELISTABARRACA JACQ...
# Mobilário, Flores, Arranjos, Cestaria  BARRACA ELIANA MARIA GONÇALVES DE OLIVEIRABARR...
# Vestuário                              BARRACA CÉLIA APARECIDA DE SOUZABARRACA CRISTI...
# Vestuário Infantil                     BARRACA CARMEN LÚCIA CARVALHO DE ALMEIDABARRAC...
#
#                                                                            NOME_FEIRANTE  \
# NOME_SETOR
# Alimentação                            CHAQUIBE HASSAN SOUKI HUNIORDAYSE PINTO NORBER...
# Arranjos e Complementos                DOMINGOS SÁVIO PEREIRA CARDOSOEDUARDO LIMA DE ...
# Artes e Pintura                        CONCEIÇÃO APARECIDA MARTINS DE OLIVEIRAHUDSON ...
# Bijouterias                            CARMEN FERNANDA ROCHA DE ALCANTARACELINIA SAMP...
# Calçados                               CENIRA CÂNDIDA DA SILVADAVIDSON MODESTOEDER HE...
# Cama, Mesa, Banho e Tapeçaria          INEZ DE FREITAS NOGUEIRA MIRANDAIOLANDA LOPES ...
# Cintos, Bolsas e Acessórios            CLÁUDIA MARIA MACHADODILEIA DE ALMEIDA MACHADO...
# Criança                                CARMEN EMMANUEL DOS SANTOS SILVACLÁUDIA REGINA...
# Decoração e Utilidades                 ILMA FERNANDES DE CARVALHO SILVAILZA FERNANDES...
# Esculturas                             JOSÉ RODRIGUES EVANGELISTAJACQUELINE DIAS DOS ...
# Mobilário, Flores, Arranjos, Cestaria  ELIANA MARIA GONÇALVES DE OLIVEIRAFRANCISCO DE...
# Vestuário                              CÉLIA APARECIDA DE SOUZACRISTIANE RODRIGUES GO...
# Vestuário Infantil                     CARMEN LÚCIA CARVALHO DE ALMEIDACECÍLIA PAGANO...
#
#                                                                            NOME_PREPOSTO  \
# NOME_SETOR
# Alimentação                            GISMAR JOSÉ GOMESDJALMA ANTÔNIO DE FREITASEVAL...
# Arranjos e Complementos                AMARILDO OTAVIO ROSAELI LOPES DE SOUZAELZA MAR...
# Artes e Pintura                        ARNALDO ALEXANDRE DE OLIVEIRAJOAO GUILHERME BA...
# Bijouterias                            KARINA RODRIGUES BRANDORFISIZENANDO JUSTINIANO...
# Calçados                               CARLOS ALBERTO FIGUEIREDO PORTOCLEBER DOS SANT...
# Cama, Mesa, Banho e Tapeçaria          JOSÉ LUCIO NOGUEIRA MIRANDAMARCINA DOLORES LOP...
# Cintos, Bolsas e Acessórios            EDUARDO MACHADO WEHBEFRANSISCO DE ASSIS MACHAD...
# Criança                                JANA FONSECA VIEIRAHERMOGENES GONÇALVES NETTOA...
# Decoração e Utilidades                 ELAINE CRISTINA DE CARVALHO R. MOREIRAIVONE FE...
# Esculturas                              WARLEY PINHEIRO EVANGELISTAEULER FERREIRA VICTOR
# Mobilário, Flores, Arranjos, Cestaria  GRACIELA GONÇALVES DE OLIVEIRADANIEL ALEXANDRE...
# Vestuário                              EDSON PIRES DE SOUZAMARIA LUCIA LOPES DA SILVA...
# Vestuário Infantil                     BARBARA ISABELLE CARVALHO DE PAULAGISELE PAGAN...
#
#                                                                                 PRODUTOS  \
# NOME_SETOR
# Alimentação                            DOCE DIVERSOCERVEJA, TORRESMO, CHIPS, AZEITONA...
# Arranjos e Complementos                ANEL, ARCO, BRINCO, PASSADOR, COLAR, PULSEIRAA...
# Artes e Pintura                        PINTURA A ÓLEO, AQUARELA, PINTURA ACRÍLICAQUAD...
# Bijouterias                            BRINCO, ANEL, PULSEIRA, COLAR, ARCOBRINCO DE P...
# Calçados                               SANDÁLIA, BOLSA EM COURO, SAPATILHA, CINTO, TA...
# Cama, Mesa, Banho e Tapeçaria          COLCHA, CHARLES, ACOLCHOADO, ALMOFADACOLCHA, A...
# Cintos, Bolsas e Acessórios            BOLSA, ORGANIZADOR DE BIJOUTERIA, NECESSÁIRE, ...
# Criança                                BOLSA DE BEBÊ, MALA DE MATERNIDADE, NECESSÁIRE...
# Decoração e Utilidades                 KIT COZINHA, CACHEPOT, PORTA GALÃO DE ÁGUA, JO...
# Esculturas                             QUADRO, QUADRO, PLACAS EM MADEIRA, ESCULTURAOR...
# Mobilário, Flores, Arranjos, Cestaria  ARRANJO DE FLOR DESIDRATADA, GALHO, QUADRO, LE...
# Vestuário                              BLUSA, BERMUDA, ROUPA DE GINÁSTICA, SAIA, VEST...
# Vestuário Infantil                     VESTIDO, CONJUNTO, MACACÃOMACACÃO, BLUSA, SAPA...
#
#                                        NUMERO_PRODUTOS_CADASTRADOS  \
# NOME_SETOR
# Alimentação                                                  733.0
# Arranjos e Complementos                                      379.0
# Artes e Pintura                                               62.0
# Bijouterias                                                 1047.0
# Calçados                                                     774.0
# Cama, Mesa, Banho e Tapeçaria                                248.0
# Cintos, Bolsas e Acessórios                                  538.0
# Criança                                                      758.0
# Decoração e Utilidades                                       423.0
# Esculturas                                                     6.0
# Mobilário, Flores, Arranjos, Cestaria                        247.0
# Vestuário                                                   1454.0
# Vestuário Infantil                                           788.0
#
#                                               AREA   DENSIDADE    PRODUTOSX2
# NOME_SETOR
# Alimentação                            3359.343283   21.820242   5398.929471
# Arranjos e Complementos                 615.329088   32.028438   3647.504054
# Artes e Pintura                         713.705731    2.606116   2894.491398
# Bijouterias                            2165.445443   88.479383  12678.779277
# Calçados                               1881.447403   65.409968  12767.340304
# Cama, Mesa, Banho e Tapeçaria           573.097787   20.237273   3054.588352
# Cintos, Bolsas e Acessórios            1514.633579   45.466568   9874.830204
# Criança                                1274.997416   62.901313   8237.244030
# Decoração e Utilidades                 1033.677527   29.927868   4618.697654
# Esculturas                               47.580382    0.252205     47.355645
# Mobilário, Flores, Arranjos, Cestaria   771.488214   14.012735   2605.495983
# Vestuário                              2591.442504  122.878561  20096.063307
# Vestuário Infantil                     1431.874390   66.590892   8760.619703

# %% [markdown]
# Observe que as contagens “totais” antes. O que acabou de acontecer? 🤯

# %% [markdown]
# ### Um exemplo ilustrativo: Animais de estimação 🐱 🐶🐹
#
# Considere os `animais de estimação` do DataFrame mostrados abaixo.

# %%
pets = pd.DataFrame().assign(
    Species=['dog', 'cat', 'cat', 'dog', 'dog', 'hamster'],
    Color=['black', 'golden', 'black', 'white', 'golden', 'golden'],
    Weight=[40, 15, 20, 80, 25, 1],
    Age=[5, 8, 9, 2, 0.5, 3]
)
pets
# Out:
#    Species   Color  Weight  Age
# 0      dog   black      40  5.0
# 1      cat  golden      15  8.0
# 2      cat   black      20  9.0
# 3      dog   white      80  2.0
# 4      dog  golden      25  0.5
# 5  hamster  golden       1  3.0

# %% [markdown]
# ### Visualizando `pets.groupby('Species').mean()`
#
# 1. **Divida** as linhas de `animais de estimação` em "grupos" de acordo com seus valores na coluna `'Espécies'`.
# 2. **Agregue** as linhas com o mesmo valor de `'Species'` tomando a `média` de todas as colunas numéricas.
# 3. **Combine** estes meios em um novo DataFrame que é indexado por `'Species'` e classificado por `'Species'` em ordem crescente.
#
# Observe que o resultado contém apenas uma linha para gatos, uma linha para cães e uma linha para hamsters!

# %%
#pets.groupby('Species')

# %% [markdown]
# ### Tutor de Pandas
#
# - Na última célula, vimos não apenas a saída do código, mas uma visualização do funcionamento interno do código.
# - Isso graças ao Pandas Tutor, uma nova ferramenta desenvolvida por [Sam Lau](https://www.samlau.me), que ministrou este curso durante o verão.
# - Pandas Tutor desenha diagramas para explicar o código `pandas` (e `babypandas`).
# - Adicione `%%pt` ao topo de uma célula de código para explicar a última linha do código `babypandas`.
# - Isso requer a importação do Pandas Tutor, o que já fizemos neste notebook.
# - Você também pode usar o Pandas Tutor através de seu site, [pandastutor.com](https://pandastutor.com/).

# %%
# Without Pandas Tutor
pets.groupby('Species').mean(numeric_only=True)
# Out:
#             Weight  Age
# Species
# cat      17.500000  8.5
# dog      48.333333  2.5
# hamster   1.000000  3.0

# %%
# %%pt

# With Pandas Tutor
# pets.groupby('Species').mean(numeric_only=True)

# %% [markdown]
# ### Voltar para solicitações de serviço Get It Done 👷

# %%
df
# Out:
#                              CODIGO_VAGA  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                             F.F2.V016
# 84                             G.F3.V052
# 85                             E.F4.V003
# 86                             E.F2.V004
# 87                             D.F2.V016
# ...                                  ...
# 1350                           G.F4.V014
# 1351                           J.F1.V004
# 1352                           D.F4.V050
# 1353                           G.F2.V010
# 1354                           G.F1.V061
#
#                                                            NOME_FANTASIA  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                              BARRACA CARMEN EMMANUEL DOS SANTOS SILVA
# 84                            BARRACA CARMEN FERNANDA ROCHA DE ALCANTARA
# 85                              BARRACA CARMEN LÚCIA CARVALHO DE ALMEIDA
# 86                                  BARRACA CECÍLIA PAGANO NEVES SALAZAR
# 87                                      BARRACA CÉLIA APARECIDA DE SOUZA
# ...                                                                  ...
# 1350                                          BARRACA HELCIO LICIO SILVA
# 1351                                       BARRACA DIEGO DOS SANTOS DIAS
# 1352                                                 BARRACA JAIR CORREA
# 1353                               BARRACA SIDNEY FERNANDO KNEIPP SOARES
# 1354                                      BARRACA REGINA GARCIA FERREIRA
#
#                                                    NOME_FEIRANTE  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                              CARMEN EMMANUEL DOS SANTOS SILVA
# 84                            CARMEN FERNANDA ROCHA DE ALCANTARA
# 85                              CARMEN LÚCIA CARVALHO DE ALMEIDA
# 86                                  CECÍLIA PAGANO NEVES SALAZAR
# 87                                      CÉLIA APARECIDA DE SOUZA
# ...                                                          ...
# 1350                                          HELCIO LICIO SILVA
# 1351                                       DIEGO DOS SANTOS DIAS
# 1352                                                 JAIR CORREA
# 1353                               SIDNEY FERNANDO KNEIPP SOARES
# 1354                                      REGINA GARCIA FERREIRA
#
#                                                    NOME_PREPOSTO  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                                           JANA FONSECA VIEIRA
# 84                                    KARINA RODRIGUES BRANDORFI
# 85                            BARBARA ISABELLE CARVALHO DE PAULA
# 86                                   GISELE PAGANO NEVES SALAZAR
# 87                                          EDSON PIRES DE SOUZA
# ...                                                          ...
# 1350                             GRAZIELA CRISTINA RAMALHO SILVA
# 1351                                     CELSO DE SOUZA LINHARES
# 1352                               Keli Aparecida Batista Correa
# 1353                                 ANA PAULA FAUSTINA DE SOUZA
# 1354                             Rejane Garcia Ferreira Clemente
#
#                                       NOME_SETOR  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                                       Criança
# 84                                   Bijouterias
# 85                            Vestuário Infantil
# 86                            Vestuário Infantil
# 87                                     Vestuário
# ...                                          ...
# 1350                                 Bijouterias
# 1351                                    Calçados
# 1352                                   Vestuário
# 1353                                 Bijouterias
# 1354                                 Bijouterias
#
#                                                                        PRODUTOS  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                            BOLSA DE BEBÊ, MALA DE MATERNIDADE, NECESSÁIRE...
# 84                                          BRINCO, ANEL, PULSEIRA, COLAR, ARCO
# 85                                                   VESTIDO, CONJUNTO, MACACÃO
# 86                                                    MACACÃO, BLUSA, SAPATINHO
# 87                            BLUSA, BERMUDA, ROUPA DE GINÁSTICA, SAIA, VEST...
# ...                                                                         ...
# 1350                          ANEL, COLAR, BROCHE, BRINCO, PULSEIRA, ALIANÇA...
# 1351                                              RASTEIRINHA, SAPATO, SANDÁLIA
# 1352                          VESTIDO DE MALHA, BATA DE TECIDO, CONJUNTO, SA...
# 1353                          COLAR, GARGANTILHA, ARCO, ANEL, PASSADOR DE CA...
# 1354                          COLAR DE METAL, PRESILHA, PASSADOR DE CABELO, ...
#
#                               NUMERO_PRODUTOS_CADASTRADOS       AREA  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                                                    5.0  11.838911
# 84                                                    5.0  11.838911
# 85                                                    3.0  11.838911
# 86                                                    3.0  11.827592
# 87                                                    7.0  11.827592
# ...                                                   ...        ...
# 1350                                                  7.0  11.838911
# 1351                                                  3.0  11.827592
# 1352                                                  5.0  11.827592
# 1353                                                  7.0  11.838911
# 1354                                                  4.0  11.827592
#
#                               DENSIDADE  PRODUTOSX2
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                             0.422336   47.355645
# 84                             0.422336   23.655184
# 85                             0.253402   35.482777
# 86                             0.253644   35.516733
# 87                             0.591836   47.355645
# ...                                 ...         ...
# 1350                           0.591271         NaN
# 1351                           0.253644         NaN
# 1352                           0.422740         NaN
# 1353                           0.591271         NaN
# 1354                           0.338192         NaN
#
# [1250 rows x 10 columns]

# %%
df.groupby('NOME_SETOR').sum()
# Out:
#                                                                              CODIGO_VAGA  \
# NOME_SETOR
# Alimentação                            Y.F1.V003Y.F1.V012Z.F4.V001Y.F1.V026X.F2.V003X...
# Arranjos e Complementos                H.F2.V004H.F2.V005H.F2.V030H.F2.V029H.F1.V014H...
# Artes e Pintura                        P.F1.V014P.F1.V017P.F1.V021P.F1.V020P.F1.V012P...
# Bijouterias                            G.F3.V052G.F3.V035G.F1.V004G.F2.V029G.F2.V012G...
# Calçados                               J.F2.V046J.F4.V035J.F1.V050J.F2.V042J.F3.V025J...
# Cama, Mesa, Banho e Tapeçaria          C.F4.V004C.F4.V015C.F1.V002C.F3.V002C.F1.V003C...
# Cintos, Bolsas e Acessórios            I.F2.V036I.F1.V026I.F4.V012I.F3.V042I.F2.V022I...
# Criança                                F.F2.V016F.F3.V022F.F2.V002F.F1.V031F.F2.V013F...
# Decoração e Utilidades                 B.F1.V018B.F4.V020B.F1.V004B.F2.V016B.F1.V008B...
# Esculturas                                                            S.F1.V002S.F1.V003
# Mobilário, Flores, Arranjos, Cestaria  A.F3.V008A.F1.V004A.F4.V012A.F4.V019A.F1.V006A...
# Vestuário                              D.F2.V016D.F2.V003D.F2.V050D.F1.V036D.F4.V058D...
# Vestuário Infantil                     E.F4.V003E.F2.V004E.F3.V016E.F4.V029E.F3.V008E...
#
#                                                                            NOME_FANTASIA  \
# NOME_SETOR
# Alimentação                            BARRACA CHAQUIBE HASSAN SOUKI HUNIORBARRACA DA...
# Arranjos e Complementos                BARRACA DOMINGOS SÁVIO PEREIRA CARDOSOBARRACA ...
# Artes e Pintura                        BARRACA CONCEIÇÃO APARECIDA MARTINS DE OLIVEIR...
# Bijouterias                            BARRACA CARMEN FERNANDA ROCHA DE ALCANTARABARR...
# Calçados                               BARRACA CENIRA CÂNDIDA DA SILVABARRACA DAVIDSO...
# Cama, Mesa, Banho e Tapeçaria          BARRACA INEZ DE FREITAS NOGUEIRA MIRANDABARRAC...
# Cintos, Bolsas e Acessórios            BARRACA CLÁUDIA MARIA MACHADOBARRACA DILEIA DE...
# Criança                                BARRACA CARMEN EMMANUEL DOS SANTOS SILVABARRAC...
# Decoração e Utilidades                 BARRACA ILMA FERNANDES DE CARVALHO SILVABARRAC...
# Esculturas                             BARRACA JOSÉ RODRIGUES EVANGELISTABARRACA JACQ...
# Mobilário, Flores, Arranjos, Cestaria  BARRACA ELIANA MARIA GONÇALVES DE OLIVEIRABARR...
# Vestuário                              BARRACA CÉLIA APARECIDA DE SOUZABARRACA CRISTI...
# Vestuário Infantil                     BARRACA CARMEN LÚCIA CARVALHO DE ALMEIDABARRAC...
#
#                                                                            NOME_FEIRANTE  \
# NOME_SETOR
# Alimentação                            CHAQUIBE HASSAN SOUKI HUNIORDAYSE PINTO NORBER...
# Arranjos e Complementos                DOMINGOS SÁVIO PEREIRA CARDOSOEDUARDO LIMA DE ...
# Artes e Pintura                        CONCEIÇÃO APARECIDA MARTINS DE OLIVEIRAHUDSON ...
# Bijouterias                            CARMEN FERNANDA ROCHA DE ALCANTARACELINIA SAMP...
# Calçados                               CENIRA CÂNDIDA DA SILVADAVIDSON MODESTOEDER HE...
# Cama, Mesa, Banho e Tapeçaria          INEZ DE FREITAS NOGUEIRA MIRANDAIOLANDA LOPES ...
# Cintos, Bolsas e Acessórios            CLÁUDIA MARIA MACHADODILEIA DE ALMEIDA MACHADO...
# Criança                                CARMEN EMMANUEL DOS SANTOS SILVACLÁUDIA REGINA...
# Decoração e Utilidades                 ILMA FERNANDES DE CARVALHO SILVAILZA FERNANDES...
# Esculturas                             JOSÉ RODRIGUES EVANGELISTAJACQUELINE DIAS DOS ...
# Mobilário, Flores, Arranjos, Cestaria  ELIANA MARIA GONÇALVES DE OLIVEIRAFRANCISCO DE...
# Vestuário                              CÉLIA APARECIDA DE SOUZACRISTIANE RODRIGUES GO...
# Vestuário Infantil                     CARMEN LÚCIA CARVALHO DE ALMEIDACECÍLIA PAGANO...
#
#                                                                            NOME_PREPOSTO  \
# NOME_SETOR
# Alimentação                            GISMAR JOSÉ GOMESDJALMA ANTÔNIO DE FREITASEVAL...
# Arranjos e Complementos                AMARILDO OTAVIO ROSAELI LOPES DE SOUZAELZA MAR...
# Artes e Pintura                        ARNALDO ALEXANDRE DE OLIVEIRAJOAO GUILHERME BA...
# Bijouterias                            KARINA RODRIGUES BRANDORFISIZENANDO JUSTINIANO...
# Calçados                               CARLOS ALBERTO FIGUEIREDO PORTOCLEBER DOS SANT...
# Cama, Mesa, Banho e Tapeçaria          JOSÉ LUCIO NOGUEIRA MIRANDAMARCINA DOLORES LOP...
# Cintos, Bolsas e Acessórios            EDUARDO MACHADO WEHBEFRANSISCO DE ASSIS MACHAD...
# Criança                                JANA FONSECA VIEIRAHERMOGENES GONÇALVES NETTOA...
# Decoração e Utilidades                 ELAINE CRISTINA DE CARVALHO R. MOREIRAIVONE FE...
# Esculturas                              WARLEY PINHEIRO EVANGELISTAEULER FERREIRA VICTOR
# Mobilário, Flores, Arranjos, Cestaria  GRACIELA GONÇALVES DE OLIVEIRADANIEL ALEXANDRE...
# Vestuário                              EDSON PIRES DE SOUZAMARIA LUCIA LOPES DA SILVA...
# Vestuário Infantil                     BARBARA ISABELLE CARVALHO DE PAULAGISELE PAGAN...
#
#                                                                                 PRODUTOS  \
# NOME_SETOR
# Alimentação                            DOCE DIVERSOCERVEJA, TORRESMO, CHIPS, AZEITONA...
# Arranjos e Complementos                ANEL, ARCO, BRINCO, PASSADOR, COLAR, PULSEIRAA...
# Artes e Pintura                        PINTURA A ÓLEO, AQUARELA, PINTURA ACRÍLICAQUAD...
# Bijouterias                            BRINCO, ANEL, PULSEIRA, COLAR, ARCOBRINCO DE P...
# Calçados                               SANDÁLIA, BOLSA EM COURO, SAPATILHA, CINTO, TA...
# Cama, Mesa, Banho e Tapeçaria          COLCHA, CHARLES, ACOLCHOADO, ALMOFADACOLCHA, A...
# Cintos, Bolsas e Acessórios            BOLSA, ORGANIZADOR DE BIJOUTERIA, NECESSÁIRE, ...
# Criança                                BOLSA DE BEBÊ, MALA DE MATERNIDADE, NECESSÁIRE...
# Decoração e Utilidades                 KIT COZINHA, CACHEPOT, PORTA GALÃO DE ÁGUA, JO...
# Esculturas                             QUADRO, QUADRO, PLACAS EM MADEIRA, ESCULTURAOR...
# Mobilário, Flores, Arranjos, Cestaria  ARRANJO DE FLOR DESIDRATADA, GALHO, QUADRO, LE...
# Vestuário                              BLUSA, BERMUDA, ROUPA DE GINÁSTICA, SAIA, VEST...
# Vestuário Infantil                     VESTIDO, CONJUNTO, MACACÃOMACACÃO, BLUSA, SAPA...
#
#                                        NUMERO_PRODUTOS_CADASTRADOS  \
# NOME_SETOR
# Alimentação                                                  733.0
# Arranjos e Complementos                                      379.0
# Artes e Pintura                                               62.0
# Bijouterias                                                 1047.0
# Calçados                                                     774.0
# Cama, Mesa, Banho e Tapeçaria                                248.0
# Cintos, Bolsas e Acessórios                                  538.0
# Criança                                                      758.0
# Decoração e Utilidades                                       423.0
# Esculturas                                                     6.0
# Mobilário, Flores, Arranjos, Cestaria                        247.0
# Vestuário                                                   1454.0
# Vestuário Infantil                                           788.0
#
#                                               AREA   DENSIDADE    PRODUTOSX2
# NOME_SETOR
# Alimentação                            3359.343283   21.820242   5398.929471
# Arranjos e Complementos                 615.329088   32.028438   3647.504054
# Artes e Pintura                         713.705731    2.606116   2894.491398
# Bijouterias                            2165.445443   88.479383  12678.779277
# Calçados                               1881.447403   65.409968  12767.340304
# Cama, Mesa, Banho e Tapeçaria           573.097787   20.237273   3054.588352
# Cintos, Bolsas e Acessórios            1514.633579   45.466568   9874.830204
# Criança                                1274.997416   62.901313   8237.244030
# Decoração e Utilidades                 1033.677527   29.927868   4618.697654
# Esculturas                               47.580382    0.252205     47.355645
# Mobilário, Flores, Arranjos, Cestaria   771.488214   14.012735   2605.495983
# Vestuário                              2591.442504  122.878561  20096.063307
# Vestuário Infantil                     1431.874390   66.590892   8760.619703

# %% [markdown]
# ### Usando `.groupby` em geral
#
# Resumindo, `.groupby` agrega todas as linhas com o mesmo valor em uma coluna especificada (por exemplo, `'NOME_SETOR'`) em uma única linha no DataFrame resultante, usando um método de agregação (por exemplo, `.sum()`) para combinar valores.
#
# 1. **Escolha uma coluna para agrupar**.
# - `.groupby(column_name)` reunirá linhas que possuem o mesmo valor na coluna especificada (`column_name`).
# - No slide anterior agrupamos por `'NOME_SETOR'`.
# 2. **Escolha um método de agregação**.
# - O método de agregação será aplicado **dentro** de cada grupo.
# - No exemplo anterior, aplicamos o método `.sum()` a cada `'NOME_SETOR'`.
# - O método de agregação é aplicado individualmente a cada coluna
# - Se não fizer sentido usar o método de agregação em uma coluna, a coluna será eliminada da saída – veremos isso com mais detalhes em breve (Tipo o nome do feirante).
# - Métodos de agregação comuns incluem `.count()`, `.sum()`, `.mean()`, `.median()`, `.max()` e `.min()`.

# %% [markdown]
# ### Observação #1
#
# - O índice mudou para nomes de SETORES.
# - Em geral, os novos rótulos de linha são os *rótulos de grupo* (ou seja, os valores exclusivos na coluna em que agrupamos).

# %%
df
# Out:
#                              CODIGO_VAGA  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                             F.F2.V016
# 84                             G.F3.V052
# 85                             E.F4.V003
# 86                             E.F2.V004
# 87                             D.F2.V016
# ...                                  ...
# 1350                           G.F4.V014
# 1351                           J.F1.V004
# 1352                           D.F4.V050
# 1353                           G.F2.V010
# 1354                           G.F1.V061
#
#                                                            NOME_FANTASIA  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                              BARRACA CARMEN EMMANUEL DOS SANTOS SILVA
# 84                            BARRACA CARMEN FERNANDA ROCHA DE ALCANTARA
# 85                              BARRACA CARMEN LÚCIA CARVALHO DE ALMEIDA
# 86                                  BARRACA CECÍLIA PAGANO NEVES SALAZAR
# 87                                      BARRACA CÉLIA APARECIDA DE SOUZA
# ...                                                                  ...
# 1350                                          BARRACA HELCIO LICIO SILVA
# 1351                                       BARRACA DIEGO DOS SANTOS DIAS
# 1352                                                 BARRACA JAIR CORREA
# 1353                               BARRACA SIDNEY FERNANDO KNEIPP SOARES
# 1354                                      BARRACA REGINA GARCIA FERREIRA
#
#                                                    NOME_FEIRANTE  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                              CARMEN EMMANUEL DOS SANTOS SILVA
# 84                            CARMEN FERNANDA ROCHA DE ALCANTARA
# 85                              CARMEN LÚCIA CARVALHO DE ALMEIDA
# 86                                  CECÍLIA PAGANO NEVES SALAZAR
# 87                                      CÉLIA APARECIDA DE SOUZA
# ...                                                          ...
# 1350                                          HELCIO LICIO SILVA
# 1351                                       DIEGO DOS SANTOS DIAS
# 1352                                                 JAIR CORREA
# 1353                               SIDNEY FERNANDO KNEIPP SOARES
# 1354                                      REGINA GARCIA FERREIRA
#
#                                                    NOME_PREPOSTO  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                                           JANA FONSECA VIEIRA
# 84                                    KARINA RODRIGUES BRANDORFI
# 85                            BARBARA ISABELLE CARVALHO DE PAULA
# 86                                   GISELE PAGANO NEVES SALAZAR
# 87                                          EDSON PIRES DE SOUZA
# ...                                                          ...
# 1350                             GRAZIELA CRISTINA RAMALHO SILVA
# 1351                                     CELSO DE SOUZA LINHARES
# 1352                               Keli Aparecida Batista Correa
# 1353                                 ANA PAULA FAUSTINA DE SOUZA
# 1354                             Rejane Garcia Ferreira Clemente
#
#                                       NOME_SETOR  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                                       Criança
# 84                                   Bijouterias
# 85                            Vestuário Infantil
# 86                            Vestuário Infantil
# 87                                     Vestuário
# ...                                          ...
# 1350                                 Bijouterias
# 1351                                    Calçados
# 1352                                   Vestuário
# 1353                                 Bijouterias
# 1354                                 Bijouterias
#
#                                                                        PRODUTOS  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                            BOLSA DE BEBÊ, MALA DE MATERNIDADE, NECESSÁIRE...
# 84                                          BRINCO, ANEL, PULSEIRA, COLAR, ARCO
# 85                                                   VESTIDO, CONJUNTO, MACACÃO
# 86                                                    MACACÃO, BLUSA, SAPATINHO
# 87                            BLUSA, BERMUDA, ROUPA DE GINÁSTICA, SAIA, VEST...
# ...                                                                         ...
# 1350                          ANEL, COLAR, BROCHE, BRINCO, PULSEIRA, ALIANÇA...
# 1351                                              RASTEIRINHA, SAPATO, SANDÁLIA
# 1352                          VESTIDO DE MALHA, BATA DE TECIDO, CONJUNTO, SA...
# 1353                          COLAR, GARGANTILHA, ARCO, ANEL, PASSADOR DE CA...
# 1354                          COLAR DE METAL, PRESILHA, PASSADOR DE CABELO, ...
#
#                               NUMERO_PRODUTOS_CADASTRADOS       AREA  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                                                    5.0  11.838911
# 84                                                    5.0  11.838911
# 85                                                    3.0  11.838911
# 86                                                    3.0  11.827592
# 87                                                    7.0  11.827592
# ...                                                   ...        ...
# 1350                                                  7.0  11.838911
# 1351                                                  3.0  11.827592
# 1352                                                  5.0  11.827592
# 1353                                                  7.0  11.838911
# 1354                                                  4.0  11.827592
#
#                               DENSIDADE
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                             0.422336
# 84                             0.422336
# 85                             0.253402
# 86                             0.253644
# 87                             0.591836
# ...                                 ...
# 1350                           0.591271
# 1351                           0.253644
# 1352                           0.422740
# 1353                           0.591271
# 1354                           0.338192
#
# [1250 rows x 9 columns]

# %%
df.groupby('NOME_SETOR').sum()
# Out:
#                                                                              CODIGO_VAGA  \
# NOME_SETOR
# Alimentação                            Y.F1.V003Y.F1.V012Z.F4.V001Y.F1.V026X.F2.V003X...
# Arranjos e Complementos                H.F2.V004H.F2.V005H.F2.V030H.F2.V029H.F1.V014H...
# Artes e Pintura                        P.F1.V014P.F1.V017P.F1.V021P.F1.V020P.F1.V012P...
# Bijouterias                            G.F3.V052G.F3.V035G.F1.V004G.F2.V029G.F2.V012G...
# Calçados                               J.F2.V046J.F4.V035J.F1.V050J.F2.V042J.F3.V025J...
# Cama, Mesa, Banho e Tapeçaria          C.F4.V004C.F4.V015C.F1.V002C.F3.V002C.F1.V003C...
# Cintos, Bolsas e Acessórios            I.F2.V036I.F1.V026I.F4.V012I.F3.V042I.F2.V022I...
# Criança                                F.F2.V016F.F3.V022F.F2.V002F.F1.V031F.F2.V013F...
# Decoração e Utilidades                 B.F1.V018B.F4.V020B.F1.V004B.F2.V016B.F1.V008B...
# Esculturas                                                            S.F1.V002S.F1.V003
# Mobilário, Flores, Arranjos, Cestaria  A.F3.V008A.F1.V004A.F4.V012A.F4.V019A.F1.V006A...
# Vestuário                              D.F2.V016D.F2.V003D.F2.V050D.F1.V036D.F4.V058D...
# Vestuário Infantil                     E.F4.V003E.F2.V004E.F3.V016E.F4.V029E.F3.V008E...
#
#                                                                            NOME_FANTASIA  \
# NOME_SETOR
# Alimentação                            BARRACA CHAQUIBE HASSAN SOUKI HUNIORBARRACA DA...
# Arranjos e Complementos                BARRACA DOMINGOS SÁVIO PEREIRA CARDOSOBARRACA ...
# Artes e Pintura                        BARRACA CONCEIÇÃO APARECIDA MARTINS DE OLIVEIR...
# Bijouterias                            BARRACA CARMEN FERNANDA ROCHA DE ALCANTARABARR...
# Calçados                               BARRACA CENIRA CÂNDIDA DA SILVABARRACA DAVIDSO...
# Cama, Mesa, Banho e Tapeçaria          BARRACA INEZ DE FREITAS NOGUEIRA MIRANDABARRAC...
# Cintos, Bolsas e Acessórios            BARRACA CLÁUDIA MARIA MACHADOBARRACA DILEIA DE...
# Criança                                BARRACA CARMEN EMMANUEL DOS SANTOS SILVABARRAC...
# Decoração e Utilidades                 BARRACA ILMA FERNANDES DE CARVALHO SILVABARRAC...
# Esculturas                             BARRACA JOSÉ RODRIGUES EVANGELISTABARRACA JACQ...
# Mobilário, Flores, Arranjos, Cestaria  BARRACA ELIANA MARIA GONÇALVES DE OLIVEIRABARR...
# Vestuário                              BARRACA CÉLIA APARECIDA DE SOUZABARRACA CRISTI...
# Vestuário Infantil                     BARRACA CARMEN LÚCIA CARVALHO DE ALMEIDABARRAC...
#
#                                                                            NOME_FEIRANTE  \
# NOME_SETOR
# Alimentação                            CHAQUIBE HASSAN SOUKI HUNIORDAYSE PINTO NORBER...
# Arranjos e Complementos                DOMINGOS SÁVIO PEREIRA CARDOSOEDUARDO LIMA DE ...
# Artes e Pintura                        CONCEIÇÃO APARECIDA MARTINS DE OLIVEIRAHUDSON ...
# Bijouterias                            CARMEN FERNANDA ROCHA DE ALCANTARACELINIA SAMP...
# Calçados                               CENIRA CÂNDIDA DA SILVADAVIDSON MODESTOEDER HE...
# Cama, Mesa, Banho e Tapeçaria          INEZ DE FREITAS NOGUEIRA MIRANDAIOLANDA LOPES ...
# Cintos, Bolsas e Acessórios            CLÁUDIA MARIA MACHADODILEIA DE ALMEIDA MACHADO...
# Criança                                CARMEN EMMANUEL DOS SANTOS SILVACLÁUDIA REGINA...
# Decoração e Utilidades                 ILMA FERNANDES DE CARVALHO SILVAILZA FERNANDES...
# Esculturas                             JOSÉ RODRIGUES EVANGELISTAJACQUELINE DIAS DOS ...
# Mobilário, Flores, Arranjos, Cestaria  ELIANA MARIA GONÇALVES DE OLIVEIRAFRANCISCO DE...
# Vestuário                              CÉLIA APARECIDA DE SOUZACRISTIANE RODRIGUES GO...
# Vestuário Infantil                     CARMEN LÚCIA CARVALHO DE ALMEIDACECÍLIA PAGANO...
#
#                                                                            NOME_PREPOSTO  \
# NOME_SETOR
# Alimentação                            GISMAR JOSÉ GOMESDJALMA ANTÔNIO DE FREITASEVAL...
# Arranjos e Complementos                AMARILDO OTAVIO ROSAELI LOPES DE SOUZAELZA MAR...
# Artes e Pintura                        ARNALDO ALEXANDRE DE OLIVEIRAJOAO GUILHERME BA...
# Bijouterias                            KARINA RODRIGUES BRANDORFISIZENANDO JUSTINIANO...
# Calçados                               CARLOS ALBERTO FIGUEIREDO PORTOCLEBER DOS SANT...
# Cama, Mesa, Banho e Tapeçaria          JOSÉ LUCIO NOGUEIRA MIRANDAMARCINA DOLORES LOP...
# Cintos, Bolsas e Acessórios            EDUARDO MACHADO WEHBEFRANSISCO DE ASSIS MACHAD...
# Criança                                JANA FONSECA VIEIRAHERMOGENES GONÇALVES NETTOA...
# Decoração e Utilidades                 ELAINE CRISTINA DE CARVALHO R. MOREIRAIVONE FE...
# Esculturas                              WARLEY PINHEIRO EVANGELISTAEULER FERREIRA VICTOR
# Mobilário, Flores, Arranjos, Cestaria  GRACIELA GONÇALVES DE OLIVEIRADANIEL ALEXANDRE...
# Vestuário                              EDSON PIRES DE SOUZAMARIA LUCIA LOPES DA SILVA...
# Vestuário Infantil                     BARBARA ISABELLE CARVALHO DE PAULAGISELE PAGAN...
#
#                                                                                 PRODUTOS  \
# NOME_SETOR
# Alimentação                            DOCE DIVERSOCERVEJA, TORRESMO, CHIPS, AZEITONA...
# Arranjos e Complementos                ANEL, ARCO, BRINCO, PASSADOR, COLAR, PULSEIRAA...
# Artes e Pintura                        PINTURA A ÓLEO, AQUARELA, PINTURA ACRÍLICAQUAD...
# Bijouterias                            BRINCO, ANEL, PULSEIRA, COLAR, ARCOBRINCO DE P...
# Calçados                               SANDÁLIA, BOLSA EM COURO, SAPATILHA, CINTO, TA...
# Cama, Mesa, Banho e Tapeçaria          COLCHA, CHARLES, ACOLCHOADO, ALMOFADACOLCHA, A...
# Cintos, Bolsas e Acessórios            BOLSA, ORGANIZADOR DE BIJOUTERIA, NECESSÁIRE, ...
# Criança                                BOLSA DE BEBÊ, MALA DE MATERNIDADE, NECESSÁIRE...
# Decoração e Utilidades                 KIT COZINHA, CACHEPOT, PORTA GALÃO DE ÁGUA, JO...
# Esculturas                             QUADRO, QUADRO, PLACAS EM MADEIRA, ESCULTURAOR...
# Mobilário, Flores, Arranjos, Cestaria  ARRANJO DE FLOR DESIDRATADA, GALHO, QUADRO, LE...
# Vestuário                              BLUSA, BERMUDA, ROUPA DE GINÁSTICA, SAIA, VEST...
# Vestuário Infantil                     VESTIDO, CONJUNTO, MACACÃOMACACÃO, BLUSA, SAPA...
#
#                                        NUMERO_PRODUTOS_CADASTRADOS  \
# NOME_SETOR
# Alimentação                                                  733.0
# Arranjos e Complementos                                      379.0
# Artes e Pintura                                               62.0
# Bijouterias                                                 1047.0
# Calçados                                                     774.0
# Cama, Mesa, Banho e Tapeçaria                                248.0
# Cintos, Bolsas e Acessórios                                  538.0
# Criança                                                      758.0
# Decoração e Utilidades                                       423.0
# Esculturas                                                     6.0
# Mobilário, Flores, Arranjos, Cestaria                        247.0
# Vestuário                                                   1454.0
# Vestuário Infantil                                           788.0
#
#                                               AREA   DENSIDADE
# NOME_SETOR
# Alimentação                            3359.343283   21.820242
# Arranjos e Complementos                 615.329088   32.028438
# Artes e Pintura                         713.705731    2.606116
# Bijouterias                            2165.445443   88.479383
# Calçados                               1881.447403   65.409968
# Cama, Mesa, Banho e Tapeçaria           573.097787   20.237273
# Cintos, Bolsas e Acessórios            1514.633579   45.466568
# Criança                                1274.997416   62.901313
# Decoração e Utilidades                 1033.677527   29.927868
# Esculturas                               47.580382    0.252205
# Mobilário, Flores, Arranjos, Cestaria   771.488214   14.012735
# Vestuário                              2591.442504  122.878561
# Vestuário Infantil                     1431.874390   66.590892

# %% [markdown]
# ### Observação #2
#
# A coluna `'NOME_FANTASIA'` e vároas outras desapareceram. Por que?

# %%
df
# Out:
#                              CODIGO_VAGA  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                             F.F2.V016
# 84                             G.F3.V052
# 85                             E.F4.V003
# 86                             E.F2.V004
# 87                             D.F2.V016
# ...                                  ...
# 1350                           G.F4.V014
# 1351                           J.F1.V004
# 1352                           D.F4.V050
# 1353                           G.F2.V010
# 1354                           G.F1.V061
#
#                                                            NOME_FANTASIA  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                              BARRACA CARMEN EMMANUEL DOS SANTOS SILVA
# 84                            BARRACA CARMEN FERNANDA ROCHA DE ALCANTARA
# 85                              BARRACA CARMEN LÚCIA CARVALHO DE ALMEIDA
# 86                                  BARRACA CECÍLIA PAGANO NEVES SALAZAR
# 87                                      BARRACA CÉLIA APARECIDA DE SOUZA
# ...                                                                  ...
# 1350                                          BARRACA HELCIO LICIO SILVA
# 1351                                       BARRACA DIEGO DOS SANTOS DIAS
# 1352                                                 BARRACA JAIR CORREA
# 1353                               BARRACA SIDNEY FERNANDO KNEIPP SOARES
# 1354                                      BARRACA REGINA GARCIA FERREIRA
#
#                                                    NOME_FEIRANTE  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                              CARMEN EMMANUEL DOS SANTOS SILVA
# 84                            CARMEN FERNANDA ROCHA DE ALCANTARA
# 85                              CARMEN LÚCIA CARVALHO DE ALMEIDA
# 86                                  CECÍLIA PAGANO NEVES SALAZAR
# 87                                      CÉLIA APARECIDA DE SOUZA
# ...                                                          ...
# 1350                                          HELCIO LICIO SILVA
# 1351                                       DIEGO DOS SANTOS DIAS
# 1352                                                 JAIR CORREA
# 1353                               SIDNEY FERNANDO KNEIPP SOARES
# 1354                                      REGINA GARCIA FERREIRA
#
#                                                    NOME_PREPOSTO  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                                           JANA FONSECA VIEIRA
# 84                                    KARINA RODRIGUES BRANDORFI
# 85                            BARBARA ISABELLE CARVALHO DE PAULA
# 86                                   GISELE PAGANO NEVES SALAZAR
# 87                                          EDSON PIRES DE SOUZA
# ...                                                          ...
# 1350                             GRAZIELA CRISTINA RAMALHO SILVA
# 1351                                     CELSO DE SOUZA LINHARES
# 1352                               Keli Aparecida Batista Correa
# 1353                                 ANA PAULA FAUSTINA DE SOUZA
# 1354                             Rejane Garcia Ferreira Clemente
#
#                                       NOME_SETOR  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                                       Criança
# 84                                   Bijouterias
# 85                            Vestuário Infantil
# 86                            Vestuário Infantil
# 87                                     Vestuário
# ...                                          ...
# 1350                                 Bijouterias
# 1351                                    Calçados
# 1352                                   Vestuário
# 1353                                 Bijouterias
# 1354                                 Bijouterias
#
#                                                                        PRODUTOS  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                            BOLSA DE BEBÊ, MALA DE MATERNIDADE, NECESSÁIRE...
# 84                                          BRINCO, ANEL, PULSEIRA, COLAR, ARCO
# 85                                                   VESTIDO, CONJUNTO, MACACÃO
# 86                                                    MACACÃO, BLUSA, SAPATINHO
# 87                            BLUSA, BERMUDA, ROUPA DE GINÁSTICA, SAIA, VEST...
# ...                                                                         ...
# 1350                          ANEL, COLAR, BROCHE, BRINCO, PULSEIRA, ALIANÇA...
# 1351                                              RASTEIRINHA, SAPATO, SANDÁLIA
# 1352                          VESTIDO DE MALHA, BATA DE TECIDO, CONJUNTO, SA...
# 1353                          COLAR, GARGANTILHA, ARCO, ANEL, PASSADOR DE CA...
# 1354                          COLAR DE METAL, PRESILHA, PASSADOR DE CABELO, ...
#
#                               NUMERO_PRODUTOS_CADASTRADOS       AREA  \
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                                                    5.0  11.838911
# 84                                                    5.0  11.838911
# 85                                                    3.0  11.838911
# 86                                                    3.0  11.827592
# 87                                                    7.0  11.827592
# ...                                                   ...        ...
# 1350                                                  7.0  11.838911
# 1351                                                  3.0  11.827592
# 1352                                                  5.0  11.827592
# 1353                                                  7.0  11.838911
# 1354                                                  4.0  11.827592
#
#                               DENSIDADE
# ID_FEIRA_AFONSO_PENA_BARRACA
# 83                             0.422336
# 84                             0.422336
# 85                             0.253402
# 86                             0.253644
# 87                             0.591836
# ...                                 ...
# 1350                           0.591271
# 1351                           0.253644
# 1352                           0.422740
# 1353                           0.591271
# 1354                           0.338192
#
# [1250 rows x 9 columns]

# %%
df.groupby('NOME_SETOR').sum()
# Out:
#                                                                              CODIGO_VAGA  \
# NOME_SETOR
# Alimentação                            Y.F1.V003Y.F1.V012Z.F4.V001Y.F1.V026X.F2.V003X...
# Arranjos e Complementos                H.F2.V004H.F2.V005H.F2.V030H.F2.V029H.F1.V014H...
# Artes e Pintura                        P.F1.V014P.F1.V017P.F1.V021P.F1.V020P.F1.V012P...
# Bijouterias                            G.F3.V052G.F3.V035G.F1.V004G.F2.V029G.F2.V012G...
# Calçados                               J.F2.V046J.F4.V035J.F1.V050J.F2.V042J.F3.V025J...
# Cama, Mesa, Banho e Tapeçaria          C.F4.V004C.F4.V015C.F1.V002C.F3.V002C.F1.V003C...
# Cintos, Bolsas e Acessórios            I.F2.V036I.F1.V026I.F4.V012I.F3.V042I.F2.V022I...
# Criança                                F.F2.V016F.F3.V022F.F2.V002F.F1.V031F.F2.V013F...
# Decoração e Utilidades                 B.F1.V018B.F4.V020B.F1.V004B.F2.V016B.F1.V008B...
# Esculturas                                                            S.F1.V002S.F1.V003
# Mobilário, Flores, Arranjos, Cestaria  A.F3.V008A.F1.V004A.F4.V012A.F4.V019A.F1.V006A...
# Vestuário                              D.F2.V016D.F2.V003D.F2.V050D.F1.V036D.F4.V058D...
# Vestuário Infantil                     E.F4.V003E.F2.V004E.F3.V016E.F4.V029E.F3.V008E...
#
#                                                                            NOME_FANTASIA  \
# NOME_SETOR
# Alimentação                            BARRACA CHAQUIBE HASSAN SOUKI HUNIORBARRACA DA...
# Arranjos e Complementos                BARRACA DOMINGOS SÁVIO PEREIRA CARDOSOBARRACA ...
# Artes e Pintura                        BARRACA CONCEIÇÃO APARECIDA MARTINS DE OLIVEIR...
# Bijouterias                            BARRACA CARMEN FERNANDA ROCHA DE ALCANTARABARR...
# Calçados                               BARRACA CENIRA CÂNDIDA DA SILVABARRACA DAVIDSO...
# Cama, Mesa, Banho e Tapeçaria          BARRACA INEZ DE FREITAS NOGUEIRA MIRANDABARRAC...
# Cintos, Bolsas e Acessórios            BARRACA CLÁUDIA MARIA MACHADOBARRACA DILEIA DE...
# Criança                                BARRACA CARMEN EMMANUEL DOS SANTOS SILVABARRAC...
# Decoração e Utilidades                 BARRACA ILMA FERNANDES DE CARVALHO SILVABARRAC...
# Esculturas                             BARRACA JOSÉ RODRIGUES EVANGELISTABARRACA JACQ...
# Mobilário, Flores, Arranjos, Cestaria  BARRACA ELIANA MARIA GONÇALVES DE OLIVEIRABARR...
# Vestuário                              BARRACA CÉLIA APARECIDA DE SOUZABARRACA CRISTI...
# Vestuário Infantil                     BARRACA CARMEN LÚCIA CARVALHO DE ALMEIDABARRAC...
#
#                                                                            NOME_FEIRANTE  \
# NOME_SETOR
# Alimentação                            CHAQUIBE HASSAN SOUKI HUNIORDAYSE PINTO NORBER...
# Arranjos e Complementos                DOMINGOS SÁVIO PEREIRA CARDOSOEDUARDO LIMA DE ...
# Artes e Pintura                        CONCEIÇÃO APARECIDA MARTINS DE OLIVEIRAHUDSON ...
# Bijouterias                            CARMEN FERNANDA ROCHA DE ALCANTARACELINIA SAMP...
# Calçados                               CENIRA CÂNDIDA DA SILVADAVIDSON MODESTOEDER HE...
# Cama, Mesa, Banho e Tapeçaria          INEZ DE FREITAS NOGUEIRA MIRANDAIOLANDA LOPES ...
# Cintos, Bolsas e Acessórios            CLÁUDIA MARIA MACHADODILEIA DE ALMEIDA MACHADO...
# Criança                                CARMEN EMMANUEL DOS SANTOS SILVACLÁUDIA REGINA...
# Decoração e Utilidades                 ILMA FERNANDES DE CARVALHO SILVAILZA FERNANDES...
# Esculturas                             JOSÉ RODRIGUES EVANGELISTAJACQUELINE DIAS DOS ...
# Mobilário, Flores, Arranjos, Cestaria  ELIANA MARIA GONÇALVES DE OLIVEIRAFRANCISCO DE...
# Vestuário                              CÉLIA APARECIDA DE SOUZACRISTIANE RODRIGUES GO...
# Vestuário Infantil                     CARMEN LÚCIA CARVALHO DE ALMEIDACECÍLIA PAGANO...
#
#                                                                            NOME_PREPOSTO  \
# NOME_SETOR
# Alimentação                            GISMAR JOSÉ GOMESDJALMA ANTÔNIO DE FREITASEVAL...
# Arranjos e Complementos                AMARILDO OTAVIO ROSAELI LOPES DE SOUZAELZA MAR...
# Artes e Pintura                        ARNALDO ALEXANDRE DE OLIVEIRAJOAO GUILHERME BA...
# Bijouterias                            KARINA RODRIGUES BRANDORFISIZENANDO JUSTINIANO...
# Calçados                               CARLOS ALBERTO FIGUEIREDO PORTOCLEBER DOS SANT...
# Cama, Mesa, Banho e Tapeçaria          JOSÉ LUCIO NOGUEIRA MIRANDAMARCINA DOLORES LOP...
# Cintos, Bolsas e Acessórios            EDUARDO MACHADO WEHBEFRANSISCO DE ASSIS MACHAD...
# Criança                                JANA FONSECA VIEIRAHERMOGENES GONÇALVES NETTOA...
# Decoração e Utilidades                 ELAINE CRISTINA DE CARVALHO R. MOREIRAIVONE FE...
# Esculturas                              WARLEY PINHEIRO EVANGELISTAEULER FERREIRA VICTOR
# Mobilário, Flores, Arranjos, Cestaria  GRACIELA GONÇALVES DE OLIVEIRADANIEL ALEXANDRE...
# Vestuário                              EDSON PIRES DE SOUZAMARIA LUCIA LOPES DA SILVA...
# Vestuário Infantil                     BARBARA ISABELLE CARVALHO DE PAULAGISELE PAGAN...
#
#                                                                                 PRODUTOS  \
# NOME_SETOR
# Alimentação                            DOCE DIVERSOCERVEJA, TORRESMO, CHIPS, AZEITONA...
# Arranjos e Complementos                ANEL, ARCO, BRINCO, PASSADOR, COLAR, PULSEIRAA...
# Artes e Pintura                        PINTURA A ÓLEO, AQUARELA, PINTURA ACRÍLICAQUAD...
# Bijouterias                            BRINCO, ANEL, PULSEIRA, COLAR, ARCOBRINCO DE P...
# Calçados                               SANDÁLIA, BOLSA EM COURO, SAPATILHA, CINTO, TA...
# Cama, Mesa, Banho e Tapeçaria          COLCHA, CHARLES, ACOLCHOADO, ALMOFADACOLCHA, A...
# Cintos, Bolsas e Acessórios            BOLSA, ORGANIZADOR DE BIJOUTERIA, NECESSÁIRE, ...
# Criança                                BOLSA DE BEBÊ, MALA DE MATERNIDADE, NECESSÁIRE...
# Decoração e Utilidades                 KIT COZINHA, CACHEPOT, PORTA GALÃO DE ÁGUA, JO...
# Esculturas                             QUADRO, QUADRO, PLACAS EM MADEIRA, ESCULTURAOR...
# Mobilário, Flores, Arranjos, Cestaria  ARRANJO DE FLOR DESIDRATADA, GALHO, QUADRO, LE...
# Vestuário                              BLUSA, BERMUDA, ROUPA DE GINÁSTICA, SAIA, VEST...
# Vestuário Infantil                     VESTIDO, CONJUNTO, MACACÃOMACACÃO, BLUSA, SAPA...
#
#                                        NUMERO_PRODUTOS_CADASTRADOS  \
# NOME_SETOR
# Alimentação                                                  733.0
# Arranjos e Complementos                                      379.0
# Artes e Pintura                                               62.0
# Bijouterias                                                 1047.0
# Calçados                                                     774.0
# Cama, Mesa, Banho e Tapeçaria                                248.0
# Cintos, Bolsas e Acessórios                                  538.0
# Criança                                                      758.0
# Decoração e Utilidades                                       423.0
# Esculturas                                                     6.0
# Mobilário, Flores, Arranjos, Cestaria                        247.0
# Vestuário                                                   1454.0
# Vestuário Infantil                                           788.0
#
#                                               AREA   DENSIDADE
# NOME_SETOR
# Alimentação                            3359.343283   21.820242
# Arranjos e Complementos                 615.329088   32.028438
# Artes e Pintura                         713.705731    2.606116
# Bijouterias                            2165.445443   88.479383
# Calçados                               1881.447403   65.409968
# Cama, Mesa, Banho e Tapeçaria           573.097787   20.237273
# Cintos, Bolsas e Acessórios            1514.633579   45.466568
# Criança                                1274.997416   62.901313
# Decoração e Utilidades                 1033.677527   29.927868
# Esculturas                               47.580382    0.252205
# Mobilário, Flores, Arranjos, Cestaria   771.488214   14.012735
# Vestuário                              2591.442504  122.878561
# Vestuário Infantil                     1431.874390   66.590892

# %% [markdown]
# ### Colunas desaparecendo ✨🐇🎩
#
# - O método de agregação – `.sum()`, neste caso – é aplicado a cada coluna.
# - Se não fizer sentido aplicá-lo a uma determinada coluna, essa coluna desaparecerá.
# - Por exemplo, não podemos somar strings, como na coluna `'NOME_FANTASIA'`.

# %% [markdown]
# ### Observação #3
#
# - O método de agregação é aplicado a cada coluna **separadamente**.
# - As linhas do DataFrame resultante precisam ser interpretadas com cuidado.

# %%
df.groupby('NOME_SETOR').mean(numeric_only=True)
# Out:
#                                        NUMERO_PRODUTOS_CADASTRADOS       AREA  \
# NOME_SETOR
# Alimentação                                               7.330000  33.593433
# Arranjos e Complementos                                   7.288462  11.833252
# Artes e Pintura                                           2.066667  23.790191
# Bijouterias                                               5.721311  11.833035
# Calçados                                                  4.867925  11.833003
# Cama, Mesa, Banho e Tapeçaria                             5.904762  13.645185
# Cintos, Bolsas e Acessórios                               4.203125  11.833075
# Criança                                                   7.359223  12.378616
# Decoração e Utilidades                                    6.130435  14.980834
# Esculturas                                                3.000000  23.790191
# Mobilário, Flores, Arranjos, Cestaria                     5.880952  18.368767
# Vestuário                                                 6.639269  11.833071
# Vestuário Infantil                                        6.512397  11.833673
#
#                                        DENSIDADE
# NOME_SETOR
# Alimentação                             0.218202
# Arranjos e Complementos                 0.615931
# Artes e Pintura                         0.086871
# Bijouterias                             0.483494
# Calçados                                0.411383
# Cama, Mesa, Banho e Tapeçaria           0.481840
# Cintos, Bolsas e Acessórios             0.355208
# Criança                                 0.610692
# Decoração e Utilidades                  0.433737
# Esculturas                              0.126102
# Mobilário, Flores, Arranjos, Cestaria   0.333637
# Vestuário                               0.561089
# Vestuário Infantil                      0.550338

# %% [markdown]
# ### Duas escolhas a serem feitas ao usar `.groupby`
#
# Como encontramos **o número de diferentes serviços solicitados em cada bairro**?
#
# **Duas opções**:
# 1. Por qual coluna devemos agrupar?
# 2. Que método de agregação devemos usar?
# - Alguns mais comuns são `.count()`, `.sum()`, `.mean()`, `.median()`, `.max()` e `.min()`.

# %%
df.groupby('NOME_SETOR').max().nunique()
# Out:
# CODIGO_VAGA                    13
# NOME_FANTASIA                  13
# NOME_FEIRANTE                  13
# NOME_PREPOSTO                  13
# PRODUTOS                       13
# NUMERO_PRODUTOS_CADASTRADOS    10
# AREA                            7
# DENSIDADE                      13
# PRODUTOSX2                     13
# dtype: int64

# %% [markdown]
# ### Observação #4
#
# - Para contar a quantidade de elementos por grupo use o `.size()`

# %%
num_barracas = df.groupby('NOME_SETOR').size()
num_barracas
# Out:
# NOME_SETOR
# Alimentação                              100
# Arranjos e Complementos                   52
# Artes e Pintura                           30
# Bijouterias                              183
# Calçados                                 159
# Cama, Mesa, Banho e Tapeçaria             42
# Cintos, Bolsas e Acessórios              128
# Criança                                  103
# Decoração e Utilidades                    69
# Esculturas                                 2
# Mobilário, Flores, Arranjos, Cestaria     42
# Vestuário                                219
# Vestuário Infantil                       121
# dtype: int64

# %% [markdown]
# ## Mais prática: conjunto de dados IMDb 🎞️
#
# - Os dados estão [aqui](https://raw.githubusercontent.com/flaviovdf/fcd/main/assets/06-GroupBy/data/imdb.csv)

# %% [markdown]
# ![](https://raw.githubusercontent.com/flaviovdf/fcd/master/assets/06-GroupBy/images/imdb.png)

# %%
# No colab, use este caminho 'https://raw.githubusercontent.com/flaviovdf/fcd/main/assets/06-GroupBy/data/imdb.csv'
imdb = pd.read_csv('imdb.csv').set_index('Title').sort_values(by='Rating')
imdb
# Out:
#                                     Votes  Rating  Year  Decade
# Title
# Akira                               91652     8.0  1988    1980
# Per un pugno di dollari            124671     8.0  1964    1960
# Guardians of the Galaxy            527349     8.0  2014    2010
# The Man Who Shot Liberty Valance    49135     8.0  1962    1960
# Underground                         39447     8.0  1995    1990
# ...                                   ...     ...   ...     ...
# Schindler's List                   761224     8.9  1993    1990
# 12 Angry Men                       384187     8.9  1957    1950
# The Godfather: Part II             692753     9.0  1974    1970
# The Shawshank Redemption          1498733     9.2  1994    1990
# The Godfather                     1027398     9.2  1972    1970
#
# [250 rows x 4 columns]

# %% [markdown]
# ### Pergunta: Quantos filmes aparecem em cada década?

# %%
imdb.groupby('Decade').count()
# Out:
#         Votes  Rating  Year
# Decade
# 1920        4       4     4
# 1930        7       7     7
# 1940       14      14    14
# 1950       30      30    30
# 1960       22      22    22
# 1970       21      21    21
# 1980       31      31    31
# 1990       42      42    42
# 2000       50      50    50
# 2010       29      29    29

# %%
# We'll learn how to make plots like this in the next lecture!
imdb.groupby('Decade').count().plot(y='Year')
# Out:
# <Axes: xlabel='Decade'>

# %% [markdown]
# ### Pergunta: Qual foi o filme de maior audiência da década de 1990?
#
# Vamos tentar fazer isso de duas maneiras diferentes.

# %% [markdown]
# #### Sem agrupamento

# %%
# Filme com a melhor avaliação da década de 1990
imdb[imdb.get('Decade') == 1980].sort_values('Rating', ascending=False).index[0]
# Out:
# 'Star Wars: Episode V - The Empire Strikes Back'

# %% [markdown]
# _Nota:_ O comando para extrair o índice de um DataFrame é `.index` - sem parênteses! Isso é diferente da maneira como extraímos colunas, com `.get()`, porque o índice não é uma coluna.

# %% [markdown]
# #### Com agrupamento

# %%
#imdb[imdb.get('Year')==2010]
imdb.groupby('Title').max()
# Out:
#                                   Votes  Rating  Year  Decade
# Title
# 12 Angry Men                     384187     8.9  1957    1950
# 12 Years a Slave                 359121     8.1  2013    2010
# 2001: A Space Odyssey            373482     8.3  1968    1960
# 3 Idiots                         167076     8.2  2009    2000
# 8½                                69988     8.1  1963    1960
# ...                                 ...     ...   ...     ...
# Who's Afraid of Virginia Woolf?   50208     8.0  1966    1960
# Witness for the Prosecution       53186     8.3  1957    1950
# X-Men: Days of Future Past       427099     8.0  2014    2010
# Yip Man                          138240     8.0  2008    2000
# Yôjinbô                           65370     8.3  1961    1960
#
# [250 rows x 4 columns]

# %%
imdb.reset_index().groupby('Decade').max()
# Out:
#                                    Title    Votes  Rating  Year
# Decade
# 1920                             The Kid    98794     8.3  1927
# 1930                    The Wizard of Oz   259235     8.5  1939
# 1940    The Treasure of the Sierra Madre   350551     8.6  1949
# 1950         Witness for the Prosecution   384187     8.9  1959
# 1960                             Yôjinbô   447875     8.9  1969
# 1970                           The Sting  1027398     9.2  1979
# 1980                    Tonari no Totoro   700283     8.7  1989
# 1990                          Unforgiven  1498733     9.2  1999
# 2000                             Yip Man  1473049     8.9  2009
# 2010          X-Men: Days of Future Past  1271949     8.7  2015

# %% [markdown]
# - Acontece que este método **não** produz a resposta correta.
# - Quando usamos um método de agregação (por exemplo, `.max()`), a agregação é feita para cada coluna individualmente.
# - Embora seja verdade que o filme com maior audiência da década de 1990 tem uma classificação de 9,2, esse filme **não** Imperdoável – em vez disso, Imperdoável é o filme mais recente no alfabeto entre todos os filmes da década de 1990.
# - Usar o `max` não ajuda aqui.

# %% [markdown]
# ## Problemas de desafio
#
# Não abordaremos esses problemas em aula, mas eles estão aqui para você praticar com alguns exemplos mais difíceis. Para acessar as soluções, você precisará assistir [this solution walkthrough video](https://youtu.be/xg7rnjWnZ48) (início às 10h).
#
# Antes de assistir ao vídeo, **tente resolver esses problemas por conta própria** – eles são uma ótima preparação para trabalhos de casa, projetos e exames!

# %% [markdown]
# ### Pergunta: Há quantos anos mais de 3 filmes foram classificados acima de 8,5?

# %%
#imdb.reset_index().groupby('Year')['Rating'].count()
#imdb[imdb.get('Rating') > 8.5]
notasAltas = imdb[imdb.get('Rating') > 8.5]
notasAltasPorAno = notasAltas.groupby('Year')['Rating'].count()
anoRecente = notasAltasPorAno[notasAltasPorAno >= 3]
anoAtual = imdb['Year'].max()
tempo = anoAtual - anoRecente.index.max()
print(f'Fazem {tempo} que nao ha 3 filmes com mais de 8.5 estrelas.')
# Out:
# Fazem 21 que nao ha 3 filmes com mais de 8.5 estrelas.

# %% [markdown]
# #### Além: Usando `.sum()` em um array/série booleana
#
# - A soma de um array/série booleana fornece uma contagem do número de elementos `True`. Isso ocorre porque Python trata `True` como 1 e `False` como 0.
# - Você pode usar esse fato aqui?

# %% [markdown]
# ### Pergunta: Dos anos com mais de 3 filmes, qual teve a classificação média mais alta?

# %% [markdown]
# ### Pergunta: Qual ano teve os títulos de filmes mais longos, em média?
#
# _Dica:_ Use `.str.len()` na coluna ou índice que contém os nomes dos filmes.

# %% [markdown]
# ### Pergunta: Qual é a classificação média dos filmes dos anos que tiveram pelo menos 3 filmes no Top 250?

# %% [markdown]
# ## Resumo, da próxima vez

# %% [markdown]
# ### Resumo
#
# - Podemos escrever consultas que envolvam múltiplas condições, desde que:
# - Coloque parênteses em todas as condições.
# - Separe as condições usando `&` se você precisar que todas sejam verdadeiras, ou `|` se você precisar que pelo menos uma seja verdadeira.
# - A chamada de método `df.groupby(column_name).agg_method()` **agrega** todas as linhas com o mesmo valor para `column_name` em uma única linha no DataFrame resultante, usando `agg_method()` para combinar valores.
# - Métodos de agregação a serem conhecidos: `.count()`, `.sum()`, `.mean()`, `.median()`, `.max()` e `.min()`.

# %% [markdown]
# ### Próxima vez
#
# Uma imagem vale mais que 1000 palavras – é hora de visualizar!
